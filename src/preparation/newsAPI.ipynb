# %%
from apikey import keys
from newsapi import NewsApiClient
from collections import defaultdict
import pandas as pd

newsapi = NewsApiClient(api_key=keys['NewsAPI']['key'])

# %%
all_sources = newsapi.get_sources()

# %%
print("NewsAPI sources")
print("{0:<30}{1}".format("Source ID", "Source Name"))
print("---------------------------------------------")
for source in all_sources['sources']:
    print("{0:<30}{1}".format(source['id'], source['name']))
# Out:
# NewsAPI sources
# Source ID                     Source Name
# ---------------------------------------------
# abc-news                      ABC News
# abc-news-au                   ABC News (AU)
# aftenposten                   Aftenposten
# al-jazeera-english            Al Jazeera English
# ansa                          ANSA.it
# argaam                        Argaam
# ars-technica                  Ars Technica
# ary-news                      Ary News
# associated-press              Associated Press
# australian-financial-review   Australian Financial Review
# axios                         Axios
# bbc-news                      BBC News
# bbc-sport                     BBC Sport
# bild                          Bild
# blasting-news-br              Blasting News (BR)
# bleacher-report               Bleacher Report
# bloomberg                     Bloomberg
# breitbart-news                Breitbart News
# business-insider              Business Insider
# business-insider-uk           Business Insider (UK)
# buzzfeed                      Buzzfeed
# cbc-news                      CBC News
# cbs-news                      CBS News
# cnbc                          CNBC
# cnn                           CNN
# cnn-es                        CNN Spanish
# crypto-coins-news             Crypto Coins News
# daily-mail                    Daily Mail
# der-tagesspiegel              Der Tagesspiegel
# die-zeit                      Die Zeit
# el-mundo                      El Mundo
# engadget                      Engadget
# entertainment-weekly          Entertainment Weekly
# espn                          ESPN
# espn-cric-info                ESPN Cric Info
# financial-post                Financial Post
# financial-times               Financial Times
# focus                         Focus
# football-italia               Football Italia
# fortune                       Fortune
# four-four-two                 FourFourTwo
# fox-news                      Fox News
# fox-sports                    Fox Sports
# globo                         Globo
# google-news                   Google News
# google-news-ar                Google News (Argentina)
# google-news-au                Google News (Australia)
# google-news-br                Google News (Brasil)
# google-news-ca                Google News (Canada)
# google-news-fr                Google News (France)
# google-news-in                Google News (India)
# google-news-is                Google News (Israel)
# google-news-it                Google News (Italy)
# google-news-ru                Google News (Russia)
# google-news-sa                Google News (Saudi Arabia)
# google-news-uk                Google News (UK)
# goteborgs-posten              Göteborgs-Posten
# gruenderszene                 Gruenderszene
# hacker-news                   Hacker News
# handelsblatt                  Handelsblatt
# ign                           IGN
# il-sole-24-ore                Il Sole 24 Ore
# independent                   Independent
# infobae                       Infobae
# info-money                    InfoMoney
# la-gaceta                     La Gaceta
# la-nacion                     La Nacion
# la-repubblica                 La Repubblica
# le-monde                      Le Monde
# lenta                         Lenta
# lequipe                       L'equipe
# les-echos                     Les Echos
# liberation                    Libération
# marca                         Marca
# mashable                      Mashable
# medical-news-today            Medical News Today
# metro                         Metro
# mirror                        Mirror
# msnbc                         MSNBC
# mtv-news                      MTV News
# mtv-news-uk                   MTV News (UK)
# national-geographic           National Geographic
# national-review               National Review
# nbc-news                      NBC News
# news24                        News24
# new-scientist                 New Scientist
# news-com-au                   News.com.au
# newsweek                      Newsweek
# new-york-magazine             New York Magazine
# next-big-future               Next Big Future
# nfl-news                      NFL News
# nhl-news                      NHL News
# nrk                           NRK
# politico                      Politico
# polygon                       Polygon
# rbc                           RBC
# recode                        Recode
# reddit-r-all                  Reddit /r/all
# reuters                       Reuters
# rt                            RT
# rte                           RTE
# rtl-nieuws                    RTL Nieuws
# sabq                          SABQ
# spiegel-online                Spiegel Online
# svenska-dagbladet             Svenska Dagbladet
# t3n                           T3n
# talksport                     TalkSport
# techcrunch                    TechCrunch
# techcrunch-cn                 TechCrunch (CN)
# techradar                     TechRadar
# the-american-conservative     The American Conservative
# the-economist                 The Economist
# the-globe-and-mail            The Globe And Mail
# the-guardian-au               The Guardian (AU)
# the-guardian-uk               The Guardian (UK)
# the-hill                      The Hill
# the-hindu                     The Hindu
# the-huffington-post           The Huffington Post
# the-irish-times               The Irish Times
# the-jerusalem-post            The Jerusalem Post
# the-lad-bible                 The Lad Bible
# the-new-york-times            The New York Times
# the-next-web                  The Next Web
# the-sport-bible               The Sport Bible
# the-telegraph                 The Telegraph
# the-times-of-india            The Times of India
# the-verge                     The Verge
# the-wall-street-journal       The Wall Street Journal
# the-washington-post           The Washington Post
# the-washington-times          The Washington Times
# time                          Time
# usa-today                     USA Today
# vice-news                     Vice News
# wired                         Wired
# wired-de                      Wired.de
# wirtschafts-woche             Wirtschafts Woche
# xinhua-net                    Xinhua Net
# ynet                          Ynet

# %%
requested_news = newsapi.get_top_headlines(country="us", category="business", page_size=100, page=1)
requested_news
# Out:
# {'status': 'ok',
#  'totalResults': 70,
#  'articles': [{'source': {'id': 'cnbc', 'name': 'CNBC'},
#    'author': 'Robert Ferris',
#    'title': 'Tesla suspends orders on website ahead of 5 pm ET announcement - CNBC',
#    'description': 'To build anticipation for its planned announcement at 5 pm ET, Tesla is redirecting users on its website to a page that says "The wait is almost over. Great things are launching at 2pm."',
#    'url': 'https://www.cnbc.com/2019/02/28/tesla-suspends-online-orders-ahead-of-announcement-redirects-website.html',
#    'urlToImage': 'https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2018/08/14/105396369-1534271228552rts4hy3.1910x1000.jpg',
#    'publishedAt': '2019-02-28T20:32:32Z',
#    'content': 'The wait is almost over, even if no one knows what we\'re waiting for. div &gt; div.group &gt; p:first-child"&gt; Electric carmaker Tesla suspended all orders on its website and redirected users to a page teasing a mystery announcement CEO Elon Musk said is co… [+488 chars]'},
#   {'source': {'id': None, 'name': 'Marketwatch.com'},
#    'author': 'Ciara Linnane',
#    'title': 'Cannabis stocks mostly higher after FDA head promises April talks on CBD regulation - MarketWatch',
#    'description': 'Cannabis stocks were mostly higher Thursday, as investors digested the latest earnings reports from the sector and comments from the head of the U.S. Food and Drug Administration on plans for regulation of CBD.',
#    'url': 'https://www.marketwatch.com/story/cannabis-stocks-mostly-higher-after-fda-head-promises-april-talks-on-cbd-regulation-2019-02-28',
#    'urlToImage': 'http://s.marketwatch.com/public/resources/MWimages/MW-GG612_gottli_ZG_20180402103516.jpg',
#    'publishedAt': '2019-02-28T19:31:00Z',
#    'content': 'Cannabis stocks were mostly higher Thursday, as investors digested the latest earnings reports from the sector and comments from the head of the U.S. Food and Drug Administration on plans for regulation of CBD. FDA Commissioner Scott Gottlieb said public meet… [+4860 chars]'},
#   {'source': {'id': None, 'name': 'Sfgate.com'},
#    'author': 'Tony Romm and Craig Timberg, The Washington Post',
#    'title': 'YouTube to ban comments on most videos featuring minors to combat child exploitation - SFGate',
#    'description': "YouTube said Thursday that it will block users from commenting on most videos that feature minors, responding to reports that pedophiles had used comments to find, track and exploit children.\nUnder YouTube's new policy, users will no longer be able to comment…",
#    'url': 'https://www.sfgate.com/business/article/YouTube-to-ban-comments-on-most-videos-featuring-13652977.php',
#    'urlToImage': 'https://s.hdnux.com/photos/01/00/56/73/16969449/3/rawImage.jpg',
#    'publishedAt': '2019-02-28T19:26:00Z',
#    'content': 'FILE - This March 20, 2018 file photo shows the YouTube app on an iPad in Baltimore. Several companies, including AT&amp;T and Nestle, are pulling advertisements from YouTube over concerns about inappropriate comments on videos of children. (AP Photo/Patrick … [+3225 chars]'},
#   {'source': {'id': None, 'name': 'Indexjournal.com'},
#    'author': 'ADAM BENSON  abenson@indexjournal.com',
#    'title': 'JC Penney to close Greenwood location | Breaking - Index-Journal',
#    'description': 'Greenwood Mall will lose one of its largest tenants this summer — J.C. Penney Co. announced Thursday it was shuttering the site in July — among 26 nationwide to be',
#    'url': 'http://www.indexjournal.com/news/breaking/j-c-penney-to-close-greenwood-location/article_aadfff57-6424-5ca7-bad9-40ac7e843126.html',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/indexjournal.com/content/tncms/assets/v3/editorial/a/17/a1766cb3-55fa-5c9f-a73a-76cbd245768e/5c783a741faa7.image.jpg?crop=1537%2C748%2C0%2C162&resize=1200%2C584&order=crop%2Cresize',
#    'publishedAt': '2019-02-28T19:20:00Z',
#    'content': 'Greenwood Mall will lose one of its largest tenants this summer J.C. Penney Co. announced Thursday it was shuttering the site in July among 26 nationwide to be closed. As part of a standard annual review, JCPenney can confirm that it will be closing its store… [+1733 chars]'},
#   {'source': {'id': None, 'name': 'Boingboing.net'},
#    'author': None,
#    'title': 'Brewers yeast genetically modified to produce THC and CBD - Boing Boing',
#    'description': 'Brewers yeast genetically modified to produce THC and CBD',
#    'url': 'https://boingboing.net/2019/02/28/yeast-are-genetically-modified.html',
#    'urlToImage': 'https://media.boingboing.net/wp-content/uploads/2018/08/640px-Marijuana_Plant_03.jpg',
#    'publishedAt': '2019-02-28T19:07:00Z',
#    'content': "Science will open the floodgates on cheap, reliable high-volume production of THC and CBD. Yeast's rapid growth and ease of culturing will likely enable new stronger-better-faster variants of both. UC Berkeley College of Chemistry : UC Berkeley synthetic biol… [+2735 chars]"},
#   {'source': {'id': None, 'name': 'Fool.com'},
#    'author': 'Rich Smith',
#    'title': 'Why Southwest Airlines Stock Just Popped - Motley Fool',
#    'description': 'Rumors of takeover interest have Southwest stock pointing north today.',
#    'url': 'https://www.fool.com/investing/2019/02/28/why-southwest-airlines-stock-just-popped.aspx',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/514304/compass-pointing-north.jpg',
#    'publishedAt': '2019-02-28T18:48:00Z',
#    'content': "What happened Southwest Airlines ( NYSE:LUV ) stock is -- what else? -- taking off today on a pair of news items, one confirmed and one not so much. What's confirmed is that yesterday, after close of trading, it was announced that the Federal Aviation Adminis… [+1475 chars]"},
#   {'source': {'id': None, 'name': 'Coindesk.com'},
#    'author': 'Zack Seward',
#    'title': 'Facebook Plans Cryptocurrency Launch in First Half of 2019: NYT Report - CoinDesk',
#    'description': 'A report from the New York Times says plans to launch a cryptocurrency product in the first half of 2019.',
#    'url': 'https://www.coindesk.com/facebook-plans-to-launch-cryptocurrency-in-first-half-of-2019-nyt-report',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2019/02/facebook.jpg',
#    'publishedAt': '2019-02-28T18:43:00Z',
#    'content': 'Facebook is talking to exchanges about potentially listing a cryptocurrency. Thats the main finding from a New York Times story published Thursday on several efforts to introduce native cryptocurrencies to widely used messaging platforms. The Times reports th… [+1187 chars]'},
#   {'source': {'id': 'recode', 'name': 'Recode'},
#    'author': 'Jason Del Rey',
#    'title': 'Amazon wants to sell "every genuine product in the world." That\'s a mistake. - Recode',
#    'description': 'The company is risking what it values most — customer trust — in pursuit of building “the everything store.”',
#    'url': 'https://www.recode.net/2019/2/28/18168354/amazon-marketplace-prime-counterfeit-goods-fake-reviews',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/JmdFds7yLnR22IAMfiNnMg09aUQ=/0x323:4496x2677/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/7543275/20161127_amazon_packages.jpg',
#    'publishedAt': '2019-02-28T18:38:48Z',
#    'content': 'On two recent trips to Amazon.com, I was in search of two very different products. One was an inexpensive pair of iPhone earbuds. The other was a body wash. Despite the products themselves having nothing in common, the two searches turned up one troubling con… [+9947 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'By MICHAEL RUBINKAM Associated Press',
#    'title': 'Walmart is getting rid of greeters; disabled workers worried - ABC News',
#    'description': '',
#    'url': 'https://abcnews.go.com/US/wireStory/walmart-rid-greeters-worrying-disabled-61389890',
#    'urlToImage': 'https://s.abcnews.com/images/US/WireAP_fcc7e961822f4f1c8a0bacb638fac223_16x9_992.jpg',
#    'publishedAt': '2019-02-28T18:19:05Z',
#    'content': None},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Jon Brodkin',
#    'title': 'After delays, OneWeb launches its first six low-Earth broadband satellites - Ars Technica',
#    'description': "OneWeb has big plan for low-latency Internet, but won't meet goal of 2019 rollout.",
#    'url': 'https://arstechnica.com/information-technology/2019/02/oneweb-launches-six-low-earth-satellites-pledges-global-broadband-in-2021/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2019/02/oneweb-satellite-760x380.jpg',
#    'publishedAt': '2019-02-28T18:12:00Z',
#    'content': 'Enlarge / Illustration of a OneWeb satellite. 21 with 20 posters participating OneWeb yesterday launched the first six low-Earth orbit satellites for its planned global broadband network, saying it will provide worldwide broadband access by 2021. The satellit… [+3160 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo.com'},
#    'author': None,
#    'title': 'Kraft Heinz lawsuit targets 3G stock transfer, writedown, SEC probe - Yahoo Finance',
#    'description': "The proposed class-action lawsuit made public on Wednesday is among the first accusing Kraft Heinz, whose other controlling shareholder is Warren Buffett's Berkshire Hathaway Inc, of defrauding shareholders about its business prospects.  Kraft Heinz's share p…",
#    'url': 'https://finance.yahoo.com/news/kraft-heinz-lawsuit-targets-3g-181123757.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/L8QnIl4qmx13QGKgSZdS2w--~B/aD01Mjk7dz04MDA7c209MTthcHBpZD15dGFjaHlvbg--/http://globalfinance.zenfs.com/images/US_AHTTP_REUTERS_OLUSBUS_WRAPPER_H_LIVE_NEW/2019-02-28T181123Z_1_LYNXNPEF1R1FB_RTROPTP_3_KRAFT-HEINZ-LAWSUIT_original.jpg',
#    'publishedAt': '2019-02-28T18:11:00Z',
#    'content': 'By Jonathan Stempel (Reuters) - Kraft Heinz Co faces a new lawsuit questioning why controlling shareholder 3G Capital transferred $1.23 billion of stock six months before the processed foods company stunned investors with a huge writedown and other bad news. … [+2471 chars]'},
#   {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#    'author': None,
#    'title': 'U.S. Said to Ready Final China Trade Deal as Hawks Urge Caution - Bloomberg',
#    'description': None,
#    'url': 'https://www.bloomberg.com/news/articles/2019-02-28/u-s-said-to-ready-final-china-trade-deal-as-hawks-urge-caution',
#    'urlToImage': None,
#    'publishedAt': '2019-02-28T18:07:00Z',
#    'content': "To continue, please click the box below to let us know you're not a robot."},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'Minyvonne Burke',
#    'title': 'Emotional support pit bull attacks 5-year-old at Portland airport, mother claims in suit - NBC News',
#    'description': 'Mirna Gonzalez said in a lawsuit filed Monday that her five-year-old daughter was bitten in the face by a woman\'s "emotional support" pit bull in December 2017.',
#    'url': 'https://www.nbcnews.com/news/us-news/emotional-support-pit-bull-attacks-5-year-old-portland-airport-n977681',
#    'urlToImage': 'https://media1.s-nbcnews.com/j/newscms/2019_09/2769231/190228-portland-airport-oregon-mn-1140_743e469f8f245ccf1ddc922933b0c396.nbcnews-fp-1200-630.jpg',
#    'publishedAt': '2019-02-28T18:07:00Z',
#    'content': 'Get breaking news alerts and special reports. The news and stories that matter, delivered weekday mornings. SUBSCRIBE Feb. 28, 2019, 6:07 PM GMT The mother of a girl who suffered serious injuries when she was bit in the face last year by a pit bull at a Portl… [+2359 chars]'},
#   {'source': {'id': None, 'name': 'Oilprice.com'},
#    'author': 'Irina Slav',
#    'title': 'Saudi Arabia Oil Exports To US Nosedive | OilPrice.com - OilPrice.com',
#    'description': 'Saudi crude exports to the U.S. have imploded this month, falling to just 20 percent what it used to be 5 years ago',
#    'url': 'https://oilprice.com/Energy/Crude-Oil/Saudi-Arabia-Oil-Exports-To-US-Nosedive.html',
#    'urlToImage': 'https://d32r1sh890xpii.cloudfront.net/article/718x300/6adcb955a78bc5fdf1e94628165b42f6.jpg',
#    'publishedAt': '2019-02-28T18:00:00Z',
#    'content': 'Saudi Arabia’s crude oil exports to U.S. are falling sharply, with shipments so far this month at just 1.6 million barrels, according to data compiled by Bloomberg, versus 5.75 million barrels a year ago. For the whole of January, Saudi Arabia exported just 2… [+1563 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Shepardson',
#    'title': 'Kia, Hyundai expand U.S. engine fire recalls by 534,000 vehicles - Reuters',
#    'description': 'Kia Motors Corp and affiliate Hyundai Motor Co said on Thursday they are recalling around 534,000 additional U.S. vehicles at risk of engine fires.',
#    'url': 'https://www.reuters.com/article/us-kia-motors-recall/kia-hyundai-expand-u-s-engine-fire-recalls-by-534000-vehicles-idUSKCN1QH2EB',
#    'urlToImage': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20190228&t=2&i=1361461582&w=1200&r=LYNXNPEF1R1DG',
#    'publishedAt': '2019-02-28T17:47:00Z',
#    'content': 'WASHINGTON (Reuters) - Kia Motors Corp and affiliate Hyundai Motor Co said on Thursday they are recalling around 534,000 additional U.S. vehicles at risk of engine fires. Kia said it is recalling 378,000 2012-2016 Kia Soul vehicles over engine damage and fire… [+2660 chars]'},
#   {'source': {'id': None, 'name': 'Nbc-2.com'},
#    'author': None,
#    'title': 'School warns of students putting vanilla extract in coffee, getting drunk - NBC2 News',
#    'description': 'Pure vanilla extract contains a minimum of 35% alcohol.',
#    'url': 'https://www.nbc-2.com/story/40046036/school-warns-of-students-putting-vanilla-extract-in-coffee-getting-drunk',
#    'urlToImage': 'https://WBBH.images.worldnow.com/images/18055359_G.jpeg?lastEditedDate=1548431437000',
#    'publishedAt': '2019-02-28T17:32:00Z',
#    'content': "TAMPA, Fla. (WFLA) - Students are buying vanilla extract and using it to get drunk. That's according to a midtown Atlanta high school, which sent a letter to parents this week, warning them to be on the lookout for Trader Joe’s Pure Bourbon Vanilla Extract, t… [+1385 chars]"},
#   {'source': {'id': None, 'name': 'Click2houston.com'},
#    'author': None,
#    'title': 'Man dipped testicles in salsa as payback for low tip, police say - KPRC Click2Houston',
#    'description': 'A Tennessee man sought revenge on a low-tipping customer by allegedly dipping his testicles in a salsa container before it was delivered.',
#    'url': 'https://www.click2houston.com/news/weird-news/man-dipped-testicles-in-salsa-as-payback-for-low-tip-police-say',
#    'urlToImage': 'https://sharedmedia.grahamdigital.com/photo/2019/02/27/Salsa%20generic.jpg_20555343_ver1.0_1280_720.jpg',
#    'publishedAt': '2019-02-28T17:26:34Z',
#    'content': 'A Tennessee man sought revenge on a low-tipping customer by allegedly dipping his testicles in a salsa container before it was delivered. Police in Maryville arrested Howard Matthew Webb, 31, after a 14-second clip of the incident was seen on Facebook. He fac… [+1015 chars]'},
#   {'source': {'id': None, 'name': 'Ajc.com'},
#    'author': 'Kelly Yamanouchi',
#    'title': 'DOT fines Delta $750,000 for long tarmac delays - Atlanta Journal Constitution',
#    'description': 'The U.S. Department of Transportation is fining Delta $750,000 for long tarmac delays in violation of the tarmac delay rule.',
#    'url': 'https://www.ajc.com/blog/airport/delta-fined-750-000-for-long-tarmac-delays/ZnSa2e8yYyMuUFFggXqWUN/',
#    'urlToImage': 'https://www.myajc.com/rf/image_large/Pub/p8/AJC/2017/12/10/Images/AP17342641437010-R0Gm3ybMhgxyHsvil40xfSL-680x383_10199535_ver1.0_640_360.jpg',
#    'publishedAt': '2019-02-28T17:18:18Z',
#    'content': 'Delta Air Lines is being fined $750,000 for flights with long tarmac delays that violated a U.S. Department of Transportation rule. However, of the $750,000, Altanta-based Delta is being credited $450,000 for compensation it gave to passengers stuck on the ta… [+926 chars]'},
#   {'source': {'id': 'cnbc', 'name': 'CNBC'},
#    'author': 'Leslie Josephs',
#    'title': 'Southwest shares gain after green light on Hawaii flights - CNBC',
#    'description': 'Southwest shares rose more than 4 percent on Thursday, a day after the airline received the blessing of the Federal Aviation Administration to fly from northern California cities to Hawaii.',
#    'url': 'https://www.cnbc.com/2019/02/28/southwest-shares-gain-after-green-light-on-hawaii-flights.html',
#    'urlToImage': 'https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2018/07/16/105332337-1531753677922gettyimages-910279234.1910x1000.jpeg',
#    'publishedAt': '2019-02-28T17:17:05Z',
#    'content': 'Southwest Airlines shares gained close to 4 percent Thursday after the low-cost airline announced it won federal approval to start its long-planned service to Hawaii, where it\'s making a big bet on growth this year. div &gt; div.group &gt; p:first-child"&gt; … [+1253 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Jamie L. LaReau',
#    'title': "GM hasn't paid US income tax for years; Ford rarely does. Both get fat refunds. Here's why - USA TODAY",
#    'description': "General Motors\xa0has not paid U.S. federal taxes in more than a decade and won't it for\xa0the next several years.\xa0Ford also gets more back than it pays.",
#    'url': 'https://www.usatoday.com/story/money/cars/2019/02/28/gm-ford-rarely-pay-federal-taxes-tax-refunds/3014770002/',
#    'urlToImage': 'https://www.gannett-cdn.com/-mm-/3be5744abb7fdbcdb315b0acb6c3dba32ea4263a/c=0-788-3658-2855/local/-/media/2017/10/30/DetroitFreeP/DetroitFreePress/636449570856209634-AP-Earns-General-Motors-NYBZ.jpg?width=3200&height=1680&fit=crop',
#    'publishedAt': '2019-02-28T17:11:00Z',
#    'content': 'General Motors stock falls on Monday after Goldman Sachs rates the stock a sell. File photo shows GM logo. (Photo: Paul Sancya, AP) General Motors has not paid federal taxes in more than a decade. In fact, it will likely not pay U.S. federal income tax for th… [+8234 chars]'},
#   {'source': {'id': 'cnbc', 'name': 'CNBC'},
#    'author': 'Lauren Thomas',
#    'title': 'Target goes preppy, again, in teaming up with Vineyard Vines - CNBC',
#    'description': 'Target is teaming up with Vineyard Vines, the clothing and accessories brand best known for its shirts embellished with a logo of a smiling pink whale.',
#    'url': 'https://www.cnbc.com/2019/02/28/target-goes-preppy-again-in-teaming-up-with-vineyard-vines.html',
#    'urlToImage': 'https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2019/02/28/105767364-1551373744432gettyimages-849913114.1910x1000.jpeg',
#    'publishedAt': '2019-02-28T16:46:59Z',
#    'content': 'Target hopes to lure younger shoppers by teaming up with preppy lifestyle brands. div &gt; div.group &gt; p:first-child"&gt; In the past, it\'s sold exclusive merchandise from clothing company Lilly Pulitzer, shoe retailer Toms and rain boot brand Hunter. On T… [+1190 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Taylor Nicole Rogers, CNN Business',
#    'title': "Amazon's new waste-reduction strategy: Deliver only once a week - CNN",
#    'description': 'Amazon wants to reduce its carbon footprint and give customers more control over when they receive their packages. The company found a way to achieve both in one new program.',
#    'url': 'https://www.cnn.com/2019/02/28/tech/amazon-day/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/190228095422-amazon-day-restricted-super-tease.jpg',
#    'publishedAt': '2019-02-28T16:36:00Z',
#    'content': None},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Sarah Perez',
#    'title': 'Report: Disney in talks with AT&T to buy WarnerMedia’s 10% Hulu stake - TechCrunch',
#    'description': 'Disney is in discussions to buy AT&T’s 10 percent stake in Hulu, which it comes into by way of its WarnerMedia acquisition, according to a report from Variety this morning. The news is not surprising – AT&T had already said it was exploring a sale. And Disney…',
#    'url': 'https://techcrunch.com/2019/02/28/report-disney-in-talks-with-att-to-buy-warnermedias-10-hulu-stake/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/02/AP_16216421048642.jpg?w=622',
#    'publishedAt': '2019-02-28T16:32:44Z',
#    'content': 'Disney is in discussions to buy AT&amp;T’s 10 percent stake in Hulu, which it comes into by way of its WarnerMedia acquisition, according to a report from Variety this morning. The news is not surprising – AT&amp;T had already said it was exploring a sale. An… [+1715 chars]'},
#   {'source': {'id': None, 'name': 'Chron.com'},
#    'author': 'By MENELAOS HADJICOSTIS, Associated Press',
#    'title': 'Cyprus: ExxonMobil finds 3rd biggest gas deposit in 2 years - Chron',
#    'description': "NICOSIA, Cyprus (AP) - ExxonMobil has made the world's third-biggest gas find in the last two years off the cost of Cyprus, the country's government said Thursday.\nEnergy Minister Georgios Lakkotrypis said the discovery of an estimated 5-8 trillion cubic feet…",
#    'url': 'https://www.chron.com/news/texas/article/Cyprus-says-ExxonMobil-has-discovered-a-natural-13651704.php',
#    'urlToImage': 'https://s.hdnux.com/photos/57/63/27/12531195/3/rawImage.jpg',
#    'publishedAt': '2019-02-28T16:24:00Z',
#    'content': 'FILE - In this April 23, 2018, file photo, the logo for ExxonMobil appears above a trading post on the floor of the New York Stock Exchange. NEXT: See earnings reports from major energy companies. FILE - In this April 23, 2018, file photo, the logo for ExxonM… [+2055 chars]'},
#   {'source': {'id': None, 'name': 'Motherjones.com'},
#    'author': 'Kevin Drum',
#    'title': 'Chart of the Day: GDP Growth in Q4 - Mother Jones',
#    'description': '',
#    'url': 'https://www.motherjones.com/kevin-drum/2019/02/chart-of-the-day-gdp-growth-in-q4/',
#    'urlToImage': 'https://www.motherjones.com/wp-content/uploads/2019/02/blog_gdp_q4_20181.gif?w=1200&h=630&crop=1',
#    'publishedAt': '2019-02-28T16:23:28Z',
#    'content': 'Looking for news you can trust? Subscribe to our free newsletters. Real GDP increased 2.6 percent in the fourth quarter: For the year, GDP increased 2.9 percent: So close! But GDP didn’t quite grow 3 percent as President Trump has been insisting it would. May… [+273 chars]'},
#   {'source': {'id': None, 'name': 'Aol.com'},
#    'author': 'Emily Rella',
#    'title': 'Uber, Lyft to offer drivers shares in stock market listing - AOL',
#    'description': 'The newspaper said Uber Technologies Inc was planning such awards for a "significant" portion of its 3 million drivers.',
#    'url': 'https://www.aol.com/article/finance/2019/02/28/uber-lyft-to-offer-drivers-shares-in-stock-market-listing-wsj/23680645/',
#    'urlToImage': 'https://o.aolcdn.com/images/dims3/GLOB/legacy_thumbnail/1028x675/format/jpg/quality/85/https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2019-02%2F043d2f60-3b72-11e9-aef7-ab734560ccde',
#    'publishedAt': '2019-02-28T16:01:13Z',
#    'content': 'Feb 28 (Reuters) - Ride-hailing firms Uber and Lyft plan to offer cash bonuses to some of their most-active or longest-serving drivers and the option to put them into shares from their stock market launches, the Wall Street Journal reported on Thursday. The n… [+2144 chars]'},
#   {'source': {'id': None, 'name': 'Barrons.com'},
#    'author': 'Andrew Bary',
#    'title': "Celgene stock is a good bet on merger with Bristol-Myers Squibb closing. - Barron's",
#    'description': 'Wellington and Starboard say they plan to vote against an acquisition by Bristol-Myers Squibb. But investors stand to make $18 a share if the deal closes.',
#    'url': 'https://www.barrons.com/articles/celgene-stock-is-a-good-bet-on-merger-with-bristol-myers-squibb-closing-51551369135',
#    'urlToImage': 'https://images.barrons.com/im-56868/social',
#    'publishedAt': '2019-02-28T15:52:00Z',
#    'content': 'Celgene stock now amounts to an intriguing bet on the outcome of its acquisition by Bristol-Myers Squibb after it took a sharp drop on the news that two influential Bristol-Myers shareholders plan to oppose the $74 billion deal. Shares of Celgene (CELG) fell … [+4435 chars]'},
#   {'source': {'id': None, 'name': 'Electrek.co'},
#    'author': None,
#    'title': 'BMW and Mercedes-Benz partner on next-gen autonomous vehicles - Electrek',
#    'description': 'BMW and Daimler, Mercedes-Benz’s parent company, have announced a new partnership to work together on the development of next-gen autonomous vehicles.',
#    'url': 'https://electrek.co/2019/02/28/bmw-mercedes-benz-partner-autonomous-vehicles/',
#    'urlToImage': 'https://electrek.co/wp-content/uploads/sites/3/2019/02/BMW-Daimler-autonomous-e1551368551828.jpg?quality=82&strip=all&w=1600',
#    'publishedAt': '2019-02-28T15:49:00Z',
#    'content': 'BMW and Daimler, Mercedes-Benz’s parent company, have announced a new partnership to work together on the development of next-gen autonomous vehicles. The two German automakers recently announced a shared $1 billion investment in a program for all-electric on… [+2246 chars]'},
#   {'source': {'id': None, 'name': 'Komonews.com'},
#    'author': 'Associated Press & KOMO Staff',
#    'title': 'Another Alaska Airlines flight odor sickens passengers, crew - KOMO News',
#    'description': 'BLOOMINGTON, Minn. &mdash; An Alaska Airlines flight was diverted to Minneapolis-St. Paul International Airport after a foul odor sickened some passengers and crew members. The flight from Chicago to Seattle made the unscheduled landing about 7 p. m. Wednesda…',
#    'url': 'https://komonews.com/news/local/another-alaska-airlines-flight-odor-sickens-passengers-crew',
#    'urlToImage': 'http://static-36.sinclairstoryline.com/resources/media/79340283-d0ac-4bf5-802e-494684988da3-large16x9_alaska_airlines_komo_09.jpg?1551367529669',
#    'publishedAt': '2019-02-28T15:26:08Z',
#    'content': 'BLOOMINGTON, Minn. — An Alaska Airlines flight was diverted to Minneapolis-St. Paul International Airport after a foul odor sickened some passengers and crew members. The flight from Chicago to Seattle made the unscheduled landing about 7 p.m. Wednesday. The … [+762 chars]'},
#   {'source': {'id': None, 'name': 'Marketwatch.com'},
#    'author': 'Andrea Riquier',
#    'title': 'Mortgage rates stay subdued as housing reform issues grab the spotlight - MarketWatch',
#    'description': 'Rates for home loans were little changed near recent lows, a breath of fresh air for the housing market that may be reinforced by policy from Washington.',
#    'url': 'https://www.marketwatch.com/story/mortgage-rates-stay-subdued-as-housing-reform-issues-grab-the-spotlight-2019-02-28',
#    'urlToImage': 'http://s.marketwatch.com/public/resources/MWimages/MW-HE763_house__ZG_20190228085009.jpg',
#    'publishedAt': '2019-02-28T15:00:00Z',
#    'content': 'For Sale sign on the front lawn of a suburban home. Rates for home loans were little changed near long-time lows, providing a little breathing room for would-be buyers even as policymakers are increasingly taking an interest in housing matters. The 30-year fi… [+3092 chars]'},
#   {'source': {'id': None, 'name': 'Wthr.com'},
#    'author': 'https://www.facebook.com/WTHR13/',
#    'title': 'Little Caesars warns of fake coupon circulating online - WTHR',
#    'description': 'Not only is the coupon fake, it could infect your computer or mobile device.',
#    'url': 'https://www.wthr.com/article/little-caesars-warns-fake-coupon-circulating-online',
#    'urlToImage': 'https://www.wthr.com/sites/default/files/styles/article_image/public/2019/02/28/littlecaesars_2006_970px.jpg?itok=rebjOlkC',
#    'publishedAt': '2019-02-28T14:47:57Z',
#    'content': 'INDIANAPOLIS (WTHR) Be careful, pizza lovers. Little Caesars warned on their Facebook page this week that a fake coupon has started circulating claiming the pizza chain will give anyone three free large pizzas on their 60th anniversary. But this hoax one has … [+386 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Saqib Shah',
#    'title': 'Amazon will let brands issue takedown strikes on fake listings - Engadget',
#    'description': "'Project Zero' relies on a mix of self-service tools and algorithms to fight counterfeits.",
#    'url': 'https://www.engadget.com/2019/02/28/amazon-brands-takedown-fake-listings/',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?thumbnail=1200%2C630&quality=80&image_uri=https%3A%2F%2Fo.aolcdn.com%2Fimages%2Fdims%3Fcrop%3D2900%252C1933%252C0%252C0%26quality%3D85%26format%3Djpg%26resize%3D1600%252C1066%26image_uri%3Dhttps%253A%252F%252Fs.yimg.com%252Fos%252Fcreatr-images%252F2019-02%252F7b5f5280-3b5e-11e9-bdf9-33118695ad9d%26client%3Da1acac3e1b3290917d92%26signature%3Da0a8103197286e8431a4b91e61f2d80478a4267b&client=amp-blogside-v2&signature=1edfeb3f77271d7b215a284827a26cf4dee40ee8',
#    'publishedAt': '2019-02-28T14:39:36Z',
#    'content': 'Instead of going through the tedious process of reporting fake listings, brands will be able to handpick them for removal. Amazon has been testing the "self-service" approach with around 15 brands for a few months, and is now rolling it out to more companies.… [+1076 chars]'},
#   {'source': {'id': None, 'name': 'Simpleflying.com'},
#    'author': 'Tom',
#    'title': 'When Will British Airways Retire Its Last 747 Now The Boeing 777X Is On Order? - Simple Flying',
#    'description': "Will today's B777-9 order from British Airways affect the Boeing 747 retirement plan? Simple Flying investigates.",
#    'url': 'https://simpleflying.com/british-airways-747-retirement-plans/',
#    'urlToImage': 'https://simpleflying.com/wp-content/uploads/2019/02/britishairways_21686374557469.jpg',
#    'publishedAt': '2019-02-28T14:21:00Z',
#    'content': 'After speculation that British Airways would order the Boeing 777X amid the 747 retirement, today the news broke that it had gone ahead. The airline has placed an exceptional order of 18 B777-9 aircraft, with 24 more options. The list price per aircraft of th… [+2867 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Ivana Kottasová, CNN Business',
#    'title': 'Aston Martin shares have plunged 40% since October - CNN',
#    'description': 'Aston Martin shares tanked nearly 20% in London after the UK carmaker revealed that rising costs had wiped out its profits for 2018.',
#    'url': 'https://www.cnn.com/2019/02/28/investing/aston-martin-shares/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/190228115922-01-aston-martin-manufacturing-file-restricted-super-tease.jpg',
#    'publishedAt': '2019-02-28T13:50:00Z',
#    'content': None},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'Michael Hill',
#    'title': 'Coyote fur is in big demand thanks to popular parkas - Associated Press',
#    'description': 'HERKIMER, N.Y. (AP) — Those fur-trimmed parkas so common on city sidewalks have become a boon to backwoods trappers. Coyote fur pelts are in big demand to provide the lush, silvery or...',
#    'url': 'https://www.apnews.com/b45b658887bd4651925a0bdc7cc2bb9a',
#    'urlToImage': 'https://storage.googleapis.com/afs-prod/media/media:e48d09cc8dce404db2e64d5dcddce80f/3000.jpeg',
#    'publishedAt': '2019-02-28T13:43:18Z',
#    'content': 'HERKIMER, N.Y. (AP) Those fur-trimmed parkas so common on city sidewalks have become a boon to backwoods trappers. Coyote fur pelts are in big demand to provide the lush, silvery or tawny-tinged arcs of fur on the hoods on Canada Goose coats and their many gl… [+3711 chars]'},
#   {'source': {'id': 'cnbc', 'name': 'CNBC'},
#    'author': 'Reuters',
#    'title': 'US jobless claims, continuing claims rise, suggesting a softening jobs market - CNBC',
#    'description': 'The number of Americans filing applications for jobless benefits increased more than expected last week and the number of people on unemployment rolls increased to a 10-month high, suggesting some slowing in the labor market.',
#    'url': 'https://www.cnbc.com/2019/02/28/weekly-jobless-claims.html',
#    'urlToImage': 'https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2017/06/23/104548323-RTX39HTO-job-fair-now-hiring.1910x1000.jpg',
#    'publishedAt': '2019-02-28T13:32:12Z',
#    'content': 'The number of Americans filing applications for jobless benefits increased more than expected last week and the number of people on unemployment rolls increased to a 10-month high, suggesting some slowing in the labor market. Initial claims for state unemploy… [+1125 chars]'},
#   {'source': {'id': None, 'name': 'Fox17.com'},
#    'author': 'KAYLIN JORGE, WZTV',
#    'title': 'You can get paid $14 an hour to taste test chocolate - WZTV',
#    'description': 'Calling all chocoholics! Confectionery company Cadbury is hiring and its looking for a chocolate taste tester. The job pays $14 an hour. The lucky hire will be part of a 12-person team tasked with giving opinions on brands like Oreos and Milk. Cadbury, at the…',
#    'url': 'http://fox17.com/news/local/get-paid-14-an-hour-to-test-chocolate',
#    'urlToImage': 'http://static-34.sinclairstoryline.com/resources/media/28aabac3-4b58-4eb6-819e-4492447e4d9b-large16x9_1280x720_40319P00ZJLBO.jpg?1551359684571',
#    'publishedAt': '2019-02-28T13:23:54Z',
#    'content': 'NASHVILLE, Tenn. (WZTV) Calling all chocoholics! Confectionery company Cadbury is hiring and its looking for a chocolate taste tester. The job pays $14 an hour. The lucky hire will be part of a 12-person team tasked with giving opinions on brands like Oreos a… [+123 chars]'},
#   {'source': {'id': 'cnbc', 'name': 'CNBC'},
#    'author': 'David Reid',
#    'title': "Rolls-Royce pulls out of race to power Boeing's new commercial plane - CNBC",
#    'description': 'The firm had hoped to supply its next generation UltraFan engine.',
#    'url': 'https://www.cnbc.com/2019/02/28/rolls-royce-pulls-out-of-race-to-power-boeing-797-plane.html',
#    'urlToImage': 'https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2015/11/12/103162015-RR.1910x1000.jpg',
#    'publishedAt': '2019-02-28T13:01:48Z',
#    'content': 'U.K. firm Rolls-Royce has pulled out of the race to provide engines for Boeing\'s new commercial aircraft. div &gt; div.group &gt; p:first-child"&gt; Boeing\'s planned New Midsize Airplane (NMA), also known as the 797 by the aviation industry, is expected by so… [+2094 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Sinéad Carew',
#    'title': 'Wall St. dips after early end to Trump-Kim summit, bleak earnings - Reuters',
#    'description': "Wall Street's main indexes went nowhere fast on Thursday with better-than-feared GDP data providing some support to counter the abrupt end to a U.S.-North Korean summit and ongoing concerns about earnings and U.S.-China trade relations.",
#    'url': 'https://www.reuters.com/article/businessNews/idUSKCN1QH1PQ',
#    'urlToImage': 'https://s1.reutersmedia.net/resources/r/?m=02&d=20190228&t=2&i=1361398247&w=1200&r=LYNXNPEF1R0Z0',
#    'publishedAt': '2019-02-28T12:55:00Z',
#    'content': 'NEW YORK (Reuters) - Wall Street’s main indexes went nowhere fast on Thursday with better-than-feared GDP data providing some support to counter the abrupt end to a U.S.-North Korean summit and ongoing concerns about earnings and U.S.-China trade relations. P… [+2841 chars]'},
#   {'source': {'id': None, 'name': 'Marketwatch.com'},
#    'author': 'Ciara Linnane',
#    'title': 'Novavax shares crater 69% premarket after trial of ResVax misses its main goal - MarketWatch',
#    'description': None,
#    'url': 'https://www.marketwatch.com/story/novavax-shares-crater-69-premarket-after-trial-of-resvax-misses-its-main-goal-2019-02-28',
#    'urlToImage': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#    'publishedAt': '2019-02-28T12:43:00Z',
#    'content': 'Novavax Inc. shares NVAX, -66.90% slid 69% in premarket trade Thursday, after the company said a trial of a treatment for the main cause of viral pneumonia in infants and young children failed to meet its main goal. Gaithersburg, Md.-based Novavax said the ph… [+1393 chars]'},
#   {'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'author': 'Associated Press',
#    'title': 'Teen video app Musical.ly agrees to $5.7 million FTC fine - Fox News',
#    'description': 'The operator of a video-sharing app popular with teenagers agreed to pay $5.7 million to settle federal allegations it\xa0illegally collected personal information from children.',
#    'url': 'https://www.foxnews.com/tech/teen-video-app-musical-ly-agrees-to-5-7-million-ftc-fine',
#    'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2019/02/musically-ap-pic.jpg',
#    'publishedAt': '2019-02-28T12:29:06Z',
#    'content': 'The operator of a video-sharing app popular with teenagers agreed to pay $5.7 million to settle federal allegations it illegally collected personal information from children. The Federal Trade Commission said the Wednesday penalty against lip-syncing app Musi… [+3402 chars]'},
#   {'source': {'id': None, 'name': 'Foxbusiness.com'},
#    'author': 'Reuters',
#    'title': "Carlos Ghosn's new legal team has applied for bail - Fox Business",
#    'description': 'Ghosn has been jailed since Nov. 19.',
#    'url': 'https://www.foxbusiness.com/business-leaders/carlos-ghosns-new-legal-team-has-applied-for-bail-tokyo-district-court',
#    'urlToImage': 'https://a57.foxnews.com/static.foxbusiness.com/foxbusiness.com/content/uploads/2018/02/0/0/Carlos-Ghosn-Nissan-Renault.jpg?ve=1&tl=1',
#    'publishedAt': '2019-02-28T11:09:56Z',
#    'content': "Forbes Media Chairman Steve Forbes, Fox News contributor Morgan Ortagus and FBN's Dagen McDowell on former Nissan Chairman Carlos Ghosn's new legal team applying for bail again. Carlos Ghosn's new legal team has applied for bail for the ousted Nissan Motor Co… [+1875 chars]"},
#   {'source': {'id': None, 'name': 'Businessreport.com'},
#    'author': 'Deanna B. Narveson',
#    'title': 'Praxair to build hydrogen plant in Louisiana - Greater Baton Rouge Business Report',
#    'description': 'Praxair Inc. announced plans this morning to build a large-scale hydrogen plant in Louisiana after signing a long-term supply contract with a major refinery in the area. The announcement did not say which refinery or where the plant will be built. The industr…',
#    'url': 'https://www.businessreport.com/industry/praxair-to-build-new-hydrogen-plant-in-louisiana',
#    'urlToImage': 'https://s25562.pcdn.co/wp-content/uploads/2018/07/Volks-Constructors-iStock.jpg',
#    'publishedAt': '2019-02-28T10:17:00Z',
#    'content': 'Praxair Inc. announced plans this morning to build a large-scale hydrogen plant in Louisiana after signing a long-term supply contract with a major refinery in the area. The announcement did not say which refinery or where the plant will be built. The industr… [+741 chars]'},
#   {'source': {'id': None, 'name': 'Forbes.com'},
#    'author': 'Zak Doffman',
#    'title': 'Huawei Claims U.S. Onslaught Is Because Their 5G Technology Prevents Widespread NSA Spying - Forbes',
#    'description': "In a well-choreographed attack, Huawei has claimed that the reason for such intense U.S. lobbying against them is that they will prevent Washington's own digital collection activities and that the claims that the company works on behalf of the Chinese state a…",
#    'url': 'https://www.forbes.com/sites/zakdoffman/2019/02/28/huawei-the-u-s-is-afraid-we-will-stop-the-nsa-spying-it-has-nothing-to-do-with-china/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/600x315/https%3A%2F%2Fblogs-images.forbes.com%2Fzakdoffman%2Ffiles%2F2019%2F02%2Fnsa2.jpg',
#    'publishedAt': '2019-02-28T07:45:00Z',
#    'content': 'Share to facebook Share to twitter Share to linkedin When it comes to high-stakes national security brinksmanship, its clear that attack is the best form of defense. At the Mobile World Congress event in Barcelona this week, Huaweis rotating chairman Guo Ping… [+19911 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Stephen Nellis',
#    'title': "Apple self-driving car layoffs give hints to division's direction - Reuters",
#    'description': 'Apple Inc said on Wednesday it planned to lay off 190 employees in its self-driving car program, Project Titan, changes that provide a rare window into the automotive technologies the company has been pursuing.',
#    'url': 'https://www.reuters.com/article/us-apple-autonomous/apple-self-driving-car-layoffs-give-hints-to-divisions-direction-idUSKCN1QG32S',
#    'urlToImage': 'https://s4.reutersmedia.net/resources/r/?m=02&d=20190228&t=2&i=1361161477&w=1200&r=LYNXNPEF1Q1ZV',
#    'publishedAt': '2019-02-28T07:02:00Z',
#    'content': '(Reuters) - Apple Inc said on Wednesday it planned to lay off 190 employees in its self-driving car program, Project Titan, changes that provide a rare window into the automotive technologies the company has been pursuing. The tech firm said in a filing with … [+2590 chars]'},
#   {'source': {'id': None, 'name': 'Cbs8.com'},
#    'author': None,
#    'title': 'Californians lose millions of dollars in recycling deposits - CBS 8 San Diego',
#    'description': "California consumers are losing out on at least $308 million in nickel deposits on cans and bottles, largely because it's increasingly difficult to find a recycling center.",
#    'url': 'http://www.cbs8.com/story/40041726/californians-lose-millions-of-dollars-in-recycling-deposits',
#    'urlToImage': 'https://KFMB.images.worldnow.com/images/18159930_G.jpg?lastEditedDate=20190228012603',
#    'publishedAt': '2019-02-28T06:26:00Z',
#    'content': "SACRAMENTO, Calif. (AP) — California consumers are losing out on at least $308 million in nickel deposits on cans and bottles, largely because it's increasingly difficult to find a recycling center. That's according to a report set for release Thursday by adv… [+560 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'Roxana Hegeman',
#    'title': 'Farm loan delinquencies highest in 9 years as prices slump - The Associated Press',
#    'description': "WICHITA, Kan. (AP) — The nation's farmers are struggling to pay back loans after years of low crop prices and export markets hit by President Donald Trump's tariffs, with a key government program...",
#    'url': 'https://www.apnews.com/7881b72df9aa41c28900acba09558e5e',
#    'urlToImage': 'https://storage.googleapis.com/afs-prod/media/media:2b35e3c91b4641818bdd1039b73924fb/3000.jpeg',
#    'publishedAt': '2019-02-28T05:10:39Z',
#    'content': 'WICHITA, Kan. (AP) The nations farmers are struggling to pay back loans after years of low crop prices and export markets hit by President Donald Trumps tariffs, with a key government program showing the highest default rate in at least nine years. Many agric… [+5483 chars]'},
#   {'source': {'id': None, 'name': 'Wkrn.com'},
#    'author': 'KTRE',
#    'title': "Maryville man accused of dipping testicles in customer's salsa - WKRN News 2",
#    'description': 'A Tennessee man was jailed on felony charges after appearing to dip his testicles into a container of salsa that a customer had ordered online.',
#    'url': 'https://www.wkrn.com/news/tennessee-news/maryville-man-accused-of-dipping-testicles-in-customers-salsa/1815551455',
#    'urlToImage': 'https://media.wkrn.com/nxs-wkrntv-media-us-east-1/photo/2019/02/27/Howard%20webb_1551323745714.jpg_75201475_ver1.0_1280_720.jpg',
#    'publishedAt': '2019-02-28T03:17:57Z',
#    'content': "31-year-old Howard Matthew Webb was arrested last week and charged with adulteration of food. (Source: Blount County Sheriff's Office) (Blount County Sheriff's Office) MARYVILLE, Tenn. (AP) - A Tennessee man was jailed on felony charges after appearing to dip… [+687 chars]"},
#   {'source': {'id': None, 'name': 'Skift.com'},
#    'author': 'Dennis Schaal',
#    'title': 'Booking and Airbnb Are Now in a Homesharing Dead Heat - Skift',
#    'description': 'Which is the biggest, baddest company offering alternative accommodations? It has been hard to tell because Airbnb is a private company and its largest',
#    'url': 'https://skift.com/2019/02/27/booking-and-airbnb-are-now-in-a-homesharing-dead-heat/',
#    'urlToImage': 'https://skift.com/wp-content/uploads/2016/08/booking.com-alternative-accommodations.jpg',
#    'publishedAt': '2019-02-28T02:09:51Z',
#    'content': 'Which is the biggest, baddest company offering alternative accommodations? It has been hard to tell because Airbnb is a private company and its largest competitor, Booking Holdings, didn’t break out its sales from vacation home and apartment rentals until now… [+3368 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Dawn Gilbertson',
#    'title': 'Southwest Airlines wing scrapes runway during aborted landing in Hartford - USA TODAY',
#    'description': 'A Southwest flight from Orlando to Hartford, Connecticut, ended up diverting to Rhode Island after trying to land three times in high winds.',
#    'url': 'https://www.usatoday.com/story/travel/flights/2019/02/27/southwest-flight-orlando-hartford-scraped-runway-amid-high-winds-diverted-providence/3005340002/',
#    'urlToImage': 'https://www.gannett-cdn.com/-mm-/f55a711468cf17c5c178842f17d8583283806688/c=0-62-1200-737/local/-/media/2019/02/23/USATODAY/usatsports/MotleyFool-TMOT-956885ae-cb1396f1.jpg?width=3200&height=1680&fit=crop',
#    'publishedAt': '2019-02-28T01:56:00Z',
#    'content': 'Even with free bags, Southwest collected $642 million in passenger fees in 2018. USA TODAY A Southwest Airlines plane attempting to land during strong winds in Connecticut this week scraped the runway and had to be pulled out of service, but not before trying… [+2873 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Paul R. La Monica, CNN Business',
#    'title': 'Weight Watchers is getting crushed by keto - CNN',
#    'description': "Weight Watchers shares sank as the company's earnings underwhelmed. The value of Oprah Winfrey's stake in Weight Watchers has plunged too. The company is facing competition from the popular keto diet.",
#    'url': 'https://www.cnn.com/2019/02/27/investing/weight-watchers-earnings-stock-ww-oprah-winfrey-keto/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/190227135055-weight-watchers-restricted-super-tease.jpg',
#    'publishedAt': '2019-02-27T22:16:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Abc7ny.com'},
#    'author': None,
#    'title': 'NJ Transit back on track after service in, out of Penn Station suspended - WABC-TV',
#    'description': 'New Jersey Transit service has resumed in and out of Penn Station New York after Amtrak wire issues briefly halted service Wednesday afternoon.',
#    'url': 'https://abc7ny.com/traffic/nj-transit-back-on-track-after-penn-station-service-suspended/5159722/',
#    'urlToImage': 'https://cdn.abcotvs.com/dip/images/4294094_092018-wabc-njtransit-file-img.jpg',
#    'publishedAt': '2019-02-27T21:38:00Z',
#    'content': 'NEW YORK (WABC) -- New Jersey Transit service has resumed in and out of New York Penn Station after Amtrak wire issues briefly halted service Wednesday afternoon. Service initially resumed with 60-minute delays that are now operating on or close to schedule. … [+508 chars]'},
#   {'source': {'id': None, 'name': 'Investors.com'},
#    'author': 'PATRICK SEITZ',
#    'title': "HP Earnings Match Views, But Revenue Comes Up Short - Investor's Business Daily",
#    'description': "PC and printer maker HP matched Wall Street's earnings target for fiscal Q1, but missed on sales. The HP earnings news sent its stock lower.",
#    'url': 'https://www.investors.com/news/technology/hp-earnings-q1-2019-hp-stock/',
#    'urlToImage': 'https://www.investors.com/wp-content/uploads/2019/02/stock-HP-3D-printer-company.jpg',
#    'publishedAt': '2019-02-27T21:21:28Z',
#    'content': "Personal computer and printer maker HP ( HPQ ) late Wednesday matched Wall Street's earnings target for its fiscal first quarter, but missed on sales. The HP earnings news pushed its stock lower in extended trading. X The Palo Alto, Calif.-based company earne… [+1741 chars]"},
#   {'source': {'id': None, 'name': 'Unionleader.com'},
#    'author': 'THOMAS BLACK Bloomberg',
#    'title': 'Stair-climbing robot designed by Dean Kamen team is hitting streets in FedEx delivery test - The Union Leader',
#    'description': 'Call it R2-D2 without the attitude.',
#    'url': 'https://www.unionleader.com/news/business/stair-climbing-robot-designed-by-dean-kamen-team-is-hitting/article_6ab72c19-662c-5836-98d8-f4e1dad8850d.html',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/unionleader.com/content/tncms/assets/v3/editorial/6/ab/6ab72c19-662c-5836-98d8-f4e1dad8850d/5c76eed5b8844.preview.jpg?resize=400%2C400',
#    'publishedAt': '2019-02-27T19:56:00Z',
#    'content': 'The FedEx Same-Day Robot uses climbing functionality developed for DEKAs iBot, a stair-climbing wheelchair. Courtesy Call it R2-D2 without the attitude. FedEx Corp. envisions a not-too-distant future in which it relies on Star Wars-style robots for more deliv… [+3740 chars]'},
#   {'source': {'id': None, 'name': 'Cleantechnica.com'},
#    'author': 'https://www.facebook.com/mr.kyle.field',
#    'title': 'The Polestar 2 Set To Bring Luxury & Performance In 2020 - CleanTechnica',
#    'description': "Polestar has taken a step towards establishing itself as a serious competitor in the performance electric vehicle space with today's unveiling of the brand's first fully electric vehicle, the Polestar 2. The reveal was streamed live\xa0this morning\xa0 from Gothenb…",
#    'url': 'https://cleantechnica.com/2019/02/27/the-polestar-2-set-to-bring-luxury-performance-in-2020/',
#    'urlToImage': 'https://cleantechnica.com/files/2019/02/polestar-2-hero-close.jpeg',
#    'publishedAt': '2019-02-27T19:39:17Z',
#    'content': 'February 27th, 2019 by Kyle Field Polestar has taken a step towards establishing itself as a serious competitor in the performance electric vehicle space with today’s unveiling of the brand’s first fully electric vehicle, the Polestar 2. The reveal was stream… [+10007 chars]'},
#   {'source': {'id': None, 'name': 'Marketwatch.com'},
#    'author': 'Tonya Garcia',
#    'title': 'Best Buy sees opportunity in foldable phones and smart home technology - MarketWatch',
#    'description': 'Best Buy is looking to innovative technologies in a variety of areas — from mobile to health — for growth potential.',
#    'url': 'https://www.marketwatch.com/story/best-buy-sees-opportunity-in-foldable-phones-and-smart-home-technology-2019-02-27',
#    'urlToImage': 'http://s.marketwatch.com/public/resources/MWimages/MW-HE717_bestbu_ZG_20190227140422.jpg',
#    'publishedAt': '2019-02-27T19:25:00Z',
#    'content': 'Best Buy Co. Inc. is looking to the future, and sees opportunity in areas including mobile devices, smart home technology and digital health. In mobile, we see new technology innovation in areas like wireless power, security and accessibility, said Best Buys … [+2721 chars]'},
#   {'source': {'id': None, 'name': 'Thestreet.com'},
#    'author': 'Timothy Collins',
#    'title': "Palo Alto's Stock Takes Off but I'm Sitting This One Out - TheStreet.com",
#    'description': "We have our reason for Wednesday's move, but I'm not sure it will hold....PANW",
#    'url': 'https://realmoney.thestreet.com/investing/palo-alto-s-stock-takes-off-but-i-m-sitting-this-one-out-14880578',
#    'urlToImage': 'http://s.thestreet.com/files/tsc/v2008/photos/contrib/uploads/e9f1ab0d-3a98-11e9-9b32-b99a628ff38f.jpg',
#    'publishedAt': '2019-02-27T18:58:04Z',
#    'content': 'Palo Alto Networks ( PANW ) "crushed" expectations on Tuesday. Ironically, they set these exact expectations a few months earlier. The company has become the security king of underpromising and over-delivering. Thus far the move has been good enough for a 6% … [+2890 chars]'},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'Reuters',
#    'title': 'U.S. issues new rules barring lithium batteries as cargo on passenger aircraft - NBCNews.com',
#    'description': 'The U.S. government issued new rules barring airlines from carrying potentially hazardous lithium-ion cells and batteries as cargo on passenger aircraft.',
#    'url': 'https://www.nbcnews.com/news/us-news/u-s-issues-new-rules-barring-lithium-batteries-cargo-passenger-n976976',
#    'urlToImage': 'https://media3.s-nbcnews.com/j/newscms/2019_09/2767611/190227-lithium-ion-battery-al-1209_ab4f9955c30f5c8c16ff1144eab6e601.nbcnews-fp-1200-630.jpg',
#    'publishedAt': '2019-02-27T17:23:00Z',
#    'content': 'Get breaking news alerts and special reports. The news and stories that matter, delivered weekday mornings. SUBSCRIBE Feb. 27, 2019, 5:23 PM GMT The U.S. government said on Wednesday it is issuing new rules barring airlines from carrying potentially hazardous… [+2844 chars]'},
#   {'source': {'id': None, 'name': 'Thetimes.co.uk'},
#    'author': None,
#    'title': "Row over Huawei risks holding back 5G and with it Europe's revival - The Times",
#    'description': 'It’s rare for Donald Trump to side with his intelligence services. Despite copious evidence of meddling, the US president does not believe that the Russian state tampered in the 2016 election. He...',
#    'url': 'https://www.thetimes.co.uk/article/europe-risks-missing-out-on-5g-technologies-thanks-to-us-paranoia-over-huawei-czhh36fvn',
#    'urlToImage': 'http://www.thetimes.co.uk/imageserver/image/methode%2Ftimes%2Fprod%2Fweb%2Fbin%2Fe57770a8-3adc-11e9-a664-d81d3e2c8975.jpg?crop=1500%2C844%2C0%2C78',
#    'publishedAt': '2019-02-27T17:00:00Z',
#    'content': 'Its rare for Donald Trump to side with his intelligence services. Despite copious evidence of meddling, the US president does not believe that the Russian state tampered in the 2016 election. He also appears to disagree with his spooks assessment of Chinas Hu… [+517 chars]'},
#   {'source': {'id': None, 'name': 'Newsok.com'},
#    'author': 'Jack Money',
#    'title': 'Chesapeake Energy reports 2018 fourth quarter, full year results - NewsOK.com',
#    'description': "Chesapeake Energy Corp. officials highlighted Improved margins, reduced debt and growing percentages of oil in the production mix Wednesday as they reported profits for 2018’s fourth quarter and the entire year. \n The company's 10 percent growth in oil produc…",
#    'url': 'https://newsok.com/article/5624221/chesapeake-energy-reports-2018-fourth-quarter-full-year-results',
#    'urlToImage': 'https://cdn2.newsok.biz/cache/r960_blur-693a46784c392990ba07c7d58fdfd982.jpg',
#    'publishedAt': '2019-02-27T16:37:22Z',
#    'content': 'After those changes, the company is operating within two basins that primarily produce natural gas, the Marcellus Shale and Gulf Coast field in northwestern Louisiana. Chesapeake officials noted 2018s significant improvement in spot pricing for natural gas in… [+1640 chars]'},
#   {'source': {'id': None, 'name': 'Barrons.com'},
#    'author': 'Teresa Rivas',
#    'title': "Lowe’s Stock Rises Because Earnings Show It’s Catching Up With Home Depot - Barron's",
#    'description': 'For years, Lowe’s lagged behind its larger rival,\xa0Home Depot. That has gradually been changing, as Lowe’s latest quarterly earnings report helps show.',
#    'url': 'https://www.barrons.com/articles/lowes-stock-rises-after-earnings-because-it-is-catching-up-with-home-depot-stock-51551281767',
#    'urlToImage': 'https://images.barrons.com/im-56507/social',
#    'publishedAt': '2019-02-27T16:09:00Z',
#    'content': 'Lowes stock (ticker: LOW) got a boost Wednesday morning from better-than-expected fourth-quarter earningswelcome news after a more downbeat report from Home Depot (HD). The back story. For years, Lowes lagged behind its larger rival, Home Depot, for many reas… [+2893 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Graham Rapier',
#    'title': "Elon Musk's erratic Twitter behavior escalated Wednesday when he changed his name to 'Elon Tusk' - Business Insider",
#    'description': 'The name change follows months of internet Musk memes like Elongated Muskrat.',
#    'url': 'https://www.businessinsider.com/elon-musk-changes-twitter-name-elon-tusk-sec-contempt-fight-2019-2',
#    'urlToImage': 'https://amp.businessinsider.com/images/5c754dd71631a378ce205226-1920-960.jpg',
#    'publishedAt': '2019-02-27T14:50:27Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Thestreet.com'},
#    'author': 'Martin Baccardax',
#    'title': 'General Electric Biopharma Sale Helps Debt Reduction, Hurts Earnings - JPM Tusa - TheStreet.com',
#    'description': "General Electric's move to sell the biopharma portion of its healthcare business to Danaher likely gives the company and extra $3 billion it can use to reduce its balance sheet, but will also cut into overall earnings in an already weakened company, according…",
#    'url': 'https://www.thestreet.com/investing/stocks/general-electric-biopharma-sale-helps-debt-reduction-hurts-earnings-jpm-tusa-14880223',
#    'urlToImage': 'http://s.thestreet.com/files/tsc/v2008/photos/contrib/uploads/ec7be5c6-127f-11e9-96fb-87a491fe7280.png',
#    'publishedAt': '2019-02-27T14:49:51Z',
#    'content': "General Electric's ( GE ) move to sell the biopharma portion of its healthcare business to Danaher Corp. ( DHR ) likely gives the company and extra $3.5 billion it can use to reduce its balance sheet, but will also cut into overall earnings in an already weak… [+3541 chars]"},
#   {'source': {'id': 'cnbc', 'name': 'CNBC'},
#    'author': 'Jeff Cox',
#    'title': 'Watch Fed Chair Jerome Powell testify live to House committee led by Rep. Maxine Waters - CNBC',
#    'description': '',
#    'url': 'https://www.cnbc.com/2019/02/27/watch-fed-chair-jerome-powell-testify-to-house-committee-led-by-rep-maxine-waters.html',
#    'urlToImage': 'https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2019/02/26/105762787-1551221186197gettyimages-1127566894.1910x1000.jpeg',
#    'publishedAt': '2019-02-27T14:46:19Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Freep.com'},
#    'author': 'Amy Huschka',
#    'title': "President Trump thanks Fiat Chrysler for 'coming back to the USA' - Detroit Free Press",
#    'description': 'Fiat Chrysler said Detroit will get a Jeep factory, as part of a $4.5 billion expansion in southeast Mich. that will mean nearly 6,500 new\xa0jobs.',
#    'url': 'https://www.freep.com/story/money/cars/chrysler/2019/02/27/donald-trump-fiat-chrysler-praise/3001686002/',
#    'urlToImage': 'https://www.gannett-cdn.com/presto/2019/02/19/PWIL/cd3b69bc-3b97-4f65-bf0b-b118d49f3deb-AP19050075367706.jpg?crop=2009,1133,x0,y0&width=3200&height=1680&fit=bounds',
#    'publishedAt': '2019-02-27T12:59:00Z',
#    'content': 'Fiat Chrysler will convert its Mack Avenue Engine factory into an assembly plant. The plant will build the next-generation Jeep Grand Cherokee and a new, large Jeep SUV. Tanya Wildt, Detroit Free Press President Donald Trump took to Twitter overnight to prais… [+2149 chars]'},
#   {'source': {'id': None, 'name': 'Inkstonenews.com'},
#    'author': 'Zheng Yangpeng',
#    'title': 'Inkstone index: shrinking billionaires - Inkstone',
#    'description': '213: the drop in the number of Chinese billionaires last\xa0year.\r...',
#    'url': 'https://www.inkstonenews.com/business/inkstone-index-greater-china-records-biggest-drop-billionaire-numbers-hurun-rich-list/article/3000975',
#    'urlToImage': 'https://cdn.i-scmp.com/sites/default/files/styles/og_image_inkstone_generic/public/d8/images/2019/02/27/1_index_20190227_v2_0.jpg?itok=tlKRuPzy',
#    'publishedAt': '2019-02-27T09:44:51Z',
#    'content': None},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Rob McLean, CNN Business',
#    'title': 'Wynn Resorts hit with record fine for ignoring Steve Wynn misconduct allegations - CNN',
#    'description': 'Wynn Resorts has been fined $20 million for its repeated failure to respond properly to sexual misconduct allegations against its founder and former CEO, Steve Wynn.',
#    'url': 'https://www.cnn.com/2019/02/27/business/wynn-resorts-nevada-gaming-commission-fine/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/190226204059-wynn-hotel-las-vegas-super-tease.jpg',
#    'publishedAt': '2019-02-27T06:26:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Katu.com'},
#    'author': 'Associated Press',
#    'title': 'Oprah-backed Weight Watchers tumbles on profit warning - KATU',
#    'description': "NEW YORK (AP) &mdash; Oprah Winfrey stands to see the value of her investment in Weight Watchers shrink after the company said it hasn't signed up as many subscribers as it hoped this winter and expects its profits to suffer. Weight Watchers International's s…",
#    'url': 'https://katu.com/news/entertainment/oprah-backed-weight-watchers-tumbles-on-profit-warning',
#    'urlToImage': 'http://static-20.sinclairstoryline.com/resources/media/3876057b-f77a-4349-9f2c-cc7c2d851389-large16x9_AP19058043066808.jpg?1551231782418',
#    'publishedAt': '2019-02-27T01:48:51Z',
#    'content': "NEW YORK (AP) — Oprah Winfrey stands to see the value of her investment in Weight Watchers shrink after the company said it hasn't signed up as many subscribers as it hoped this winter and expects its profits to suffer. Weight Watchers International's stock t… [+538 chars]"},
#   {'source': {'id': None, 'name': 'Winknews.com'},
#    'author': None,
#    'title': "AT&T's Time Warner takeover has already reshaped media world - Wink News",
#    'description': 'AT&T’s Time Warner takeover has already reshaped media world as a federal appeals court on Tuesday upheld AT&T’s $81 billion takeover of Time Warner.',
#    'url': 'https://www.winknews.com/2019/02/26/atts-time-warner-takeover-has-already-reshaped-media-world/',
#    'urlToImage': 'https://cdn.winknews.com/wp-content/uploads/2019/02/Clouds-are-reflected-in-the-glass-facade-of-the-Time-Warner-building-in-New-York.-AP-photo.jpeg',
#    'publishedAt': '2019-02-27T01:16:00Z',
#    'content': 'A federal appeals court on Tuesday upheld AT&amp;Ts $81 billion takeover of Time Warner, approving one of the biggest media deals on record in the face of opposition from the Trump administration. The combination of one of the countrys largest wireless carrie… [+2962 chars]'},
#   {'source': {'id': None, 'name': 'Youtube.com'},
#    'author': None,
#    'title': 'Passengers Cheer When Stuck Train Moves After 30 Hours - Inside Edition',
#    'description': 'Nearly 200 people who were stuck on an Amtrak train for 36 hours are finally on the move after being trapped on a snowy stretch of track just south of Eugene...',
#    'url': 'https://www.youtube.com/watch?v=tz6K9z6t1yE',
#    'urlToImage': 'https://i.ytimg.com/vi/tz6K9z6t1yE/maxresdefault.jpg',
#    'publishedAt': '2019-02-26T22:30:04Z',
#    'content': 'Nearly 200 people who were stuck on an Amtrak train for 36 hours are finally on the move after being trapped on a snowy stretch of track just south of Eugene, Oregon. All 183 passengers and 12 crew members became trapped in the snow on board the train on Sund… [+213 chars]'}]}

# %%
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2019-02-01',
                                      sort_by='relevancy')

# %%
print("Printing first 5 articles about 'bitcoin' from 'bbc-news' and 'the-verge'")
print()
for article in all_articles['articles'][:5]:
    print(article['source']['name'] + "\n" + article['title'] + "\n" + article['description'] + "\n------")
# Out:
# Printing first 5 articles about 'bitcoin' from 'bbc-news' and 'the-verge'
#
# TechCrunch
# Coinbase users can now withdraw Bitcoin SV following BCH fork
# If you’re a Coinbase user, you may have seen some new tokens on your account. The Bitcoin Cash chain split into two different chains back in November. It means that if you held Bitcoin Cash on November 15, you became the lucky owner of Bitcoin SV and Bitcoin …
# ------
# The Verge
# The Samsung Galaxy S10 has a cryptocurrency wallet built in
# Samsung is the first major smartphone maker to include a cryptocurrency wallet in its latest flagship Galaxy S10 phones. The wallet lets users store bitcoin, Ethereum, and a beauty-related cryptocurrency called Cosmo Coin. It’s a cold storage wallet, meaning …
# ------
# TechCrunch
# Coinbase Pro is about to let you trade XRP
# On Tuesday, Coinbase announced that XRP will be the latest cryptocurrency to hit its pro-level trading platform. Coinbase Pro will allow users to transfer XRP to the platform right away (“After 10am on February 25”) but there will be at least a 12 hour delay …
# ------
# TechCrunch
# Atrium, Justin Kan’s legal tech startup, launches a fintech and blockchain division
# Atrium, the legal startup co-founder by Justin Kan of Twitch fame, is jumping into the blockchain space today. The company has raised plenty of money — including $65 million from A16z last September — so rather than an ICO or token sale, this is a consultancy…
# ------
# BBC News
# Quadriga: The cryptocurrency exchange that lost $135m
# When Quadriga's founder died he left behind a mystery: what happened to millions in cryptocurrency?
# ------

# %%
import json
with open('all_en_sources.json', 'r') as f:
    all_en_sources_json = json.load(f)

all_en_sources = set()
for source in all_en_sources_json['sources']:
    all_en_sources.add(source['id'])
    
all_en_sources = ','.join(all_en_sources)
print(all_en_sources)
# Out:
# the-guardian-uk,engadget,mtv-news-uk,bloomberg,abc-news,the-telegraph,espn-cric-info,politico,four-four-two,medical-news-today,the-next-web,rte,msnbc,the-new-york-times,google-news,news-com-au,entertainment-weekly,cnbc,next-big-future,the-hill,the-verge,national-geographic,nfl-news,google-news-in,buzzfeed,the-economist,financial-post,reuters,mashable,ars-technica,google-news-ca,hacker-news,al-jazeera-english,abc-news-au,techcrunch,metro,the-lad-bible,fox-news,axios,financial-times,mtv-news,polygon,wired,bleacher-report,new-york-magazine,the-huffington-post,new-scientist,time,breitbart-news,independent,espn,associated-press,news24,the-guardian-au,mirror,nhl-news,australian-financial-review,the-washington-post,techradar,the-hindu,national-review,business-insider,the-sport-bible,bbc-sport,fox-sports,the-irish-times,daily-mail,vice-news,nbc-news,crypto-coins-news,talksport,reddit-r-all,the-american-conservative,the-wall-street-journal,cbc-news,recode,the-times-of-india,the-washington-times,fortune,the-jerusalem-post,business-insider-uk,usa-today,newsweek,cbs-news,google-news-au,ign,bbc-news,cnn,the-globe-and-mail,google-news-uk,football-italia

# %%
def to_csv(news, filename):
    all_news = []
    for article in news:
        all_news.append([article['source']['name'], article['publishedAt'], article['title'], article['description']])
    pd.DataFrame(all_news, columns=['source', 'date', 'title', 'description']).to_csv(filename)

# %%
categories = ['health', 'business', 'sports'] # politics is not an option
max_results = 1000  # max limit of article querying

for category in categories:
    category_news = []
    
    num_articles = 0
    requested_articles = 1
    page = 1

    while num_articles < min(requested_articles, max_results):
        requested_news = newsapi.get_top_headlines(category=category, page=page, page_size=100, country='us')

        requested_articles = requested_news['totalResults']
        num_articles += len(requested_news['articles'])
        category_news.extend(requested_news['articles'])
        page += 1
        
    to_csv(category_news, "sentiments/{}.csv".format(category))
