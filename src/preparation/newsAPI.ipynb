# %%
from apikey import keys
from newsapi import NewsApiClient
from collections import defaultdict
import pandas as pd

newsapi = NewsApiClient(api_key=keys['NewsAPI'])

# %%
all_sources = newsapi.get_sources()
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-84-0a4935babeb1> in <module>()
# ----> 1 all_sources = newsapi.get_sources()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/newsapi/newsapi_client.py in get_sources(self, category, language, country)
#     313         # Check Status of Request
#     314         if r.status_code != requests.codes.ok:
# --> 315             raise NewsAPIException(r.json())
#     316
#     317         return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 1,000 requests over a 24 hour period (250 requests available every 6 hours). Please upgrade to a paid plan if you need more requests.'}

# %%
print("NewsAPI sources")
print("{0:<30}{1}".format("Source ID", "Source Name"))
print("---------------------------------------------")
for source in sources['sources']:
    print("{0:<30}{1}".format(source['id'], source['name']))
# Out:
# NewsAPI sources
# Source ID                     Source Name
# ---------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-7b4a43942a1c> in <module>()
#       2 print("{0:<30}{1}".format("Source ID", "Source Name"))
#       3 print("---------------------------------------------")
# ----> 4 for source in sources['sources']:
#       5     print("{0:<30}{1}".format(source['id'], source['name']))
#
# TypeError: 'set' object is not subscriptable

# %%
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2019-01-23',
                                      language='en',
                                      sort_by='relevancy')

# %%
print("Printing first 5 articles about 'bitcoin' from 'bbc-news' and 'the-verge'")
print()
for article in all_articles['articles'][:5]:
    print(article['source']['name'] + "\n" + article['title'] + "\n" + article['description'] + "\n------")
# Out:
# Printing first 5 articles about 'bitcoin' from 'bbc-news' and 'the-verge'
#
# TechCrunch
# Coinbase users can now withdraw Bitcoin SV following BCH fork
# If you’re a Coinbase user, you may have seen some new tokens on your account. The Bitcoin Cash chain split into two different chains back in November. It means that if you held Bitcoin Cash on November 15, you became the lucky owner of Bitcoin SV and Bitcoin …
# ------
# TechCrunch
# Atrium, Justin Kan’s legal tech startup, launches a fintech and blockchain division
# Atrium, the legal startup co-founder by Justin Kan of Twitch fame, is jumping into the blockchain space today. The company has raised plenty of money — including $65 million from A16z last September — so rather than an ICO or token sale, this is a consultancy…
# ------
# BBC News
# Quadriga: The cryptocurrency exchange that lost $135m
# When Quadriga's founder died he left behind a mystery: what happened to millions in cryptocurrency?
# ------
# TechCrunch
# Security token offerings aren’t looking much better in 2019
# Pressed to explain who is using them, and why, 99 percent of cryptocurrencies let out all their air, go flying around the room making a raspberry sound, hit the wall and fall behind the couch forever. The party is over. A few, however, can present a credible …
# ------
# TechCrunch
# ClassPass, Gfycat, StreetEasy hit in latest round of mass site hacks
# In just a week, a single seller put close to 750 million records from 24 hacked sites up for sale. Now, the hacker has struck again. The hacker, whose identity isn’t known, began listing user data from several major websites — including MyFitnessPal, 500px an…
# ------

# %%
categories = ['health', 'business', 'sports'] # politics is not an option
all_news = defaultdict(list)
max_results = 1000  # max limit of article querying

# %%
for category in categories:
    num_articles = 0
    requested_articles = 1
    page = 1

    while num_articles < min(requested_articles, max_results):
        requested_news = newsapi.get_top_headlines(category=category, page=page, language='en')

        requested_articles = requested_news['totalResults']
        num_articles += len(requested_news['articles'])
        page += 1
        all_news[category].extend(requested_news['articles'])
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-78-319d8c2e14c8> in <module>()
#       5
#       6     while num_articles < min(requested_articles, max_results):
# ----> 7         requested_news = newsapi.get_top_headlines(category=category, page=page, language='en')
#       8
#       9         requested_articles = requested_news['totalResults']
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/newsapi/newsapi_client.py in get_top_headlines(self, q, sources, language, country, category, page_size, page)
#     117         # Check Status of Request
#     118         if r.status_code != requests.codes.ok:
# --> 119             raise NewsAPIException(r.json())
#     120
#     121         return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 1,000 requests over a 24 hour period (250 requests available every 6 hours). Please upgrade to a paid plan if you need more requests.'}

# %%
sources = set()
for category in categories:
    for article in all_news[category]:
        sources.add(article['source']['name'])
print(len(sources))
# Out:
# 1175

# %%
import json
with open('all_en_sources.json', 'r') as f:
    all_en_sources_json = json.load(f)

all_en_sources = set()
for source in all_en_sources_json['sources']:
    all_en_sources.add(source['name'])
    
print(len(all_en_sources))
# Out:
# 91

# %%
len(sources and all_en_sources)
# Out:
# 91

# %%
from textblob import TextBlob
for article in all_news['business']:
    print(article['title'])
    print(TextBlob(article['title']).sentiment)
# Out:
# Okända gifterna i vanliga grönsaker – så farliga är de för dig - 24kristianstad.se
# Sentiment(polarity=0.0, subjectivity=0.0)
# Un symposium regroupant Boeing et les industries de l'Aéronautique - hibapress
# Sentiment(polarity=0.0, subjectivity=0.0)
# Magna ganó 2.296 millones de dólares en 2018, un 0,77 % más - Investing.com España
# Sentiment(polarity=0.0, subjectivity=0.0)
# 97-year-old Macau tycoon's kids race to revive his casino empire - Business Mirror
# Sentiment(polarity=0.0, subjectivity=0.0)
# 94 döda av hembränd sprit i Indien - Sveriges Television
# Sentiment(polarity=0.0, subjectivity=0.0)
# CIH Bank: 450 MDH de bénéfices en 2018 - Leseco.ma
# Sentiment(polarity=0.0, subjectivity=0.0)
# "ดวงฤทธิ์" จ่อฟ้องล้มออกแบบ บอร์ดทอท.ดันต่อเทอร์มินอล 2 - ประชาชาติธุรกิจ
# Sentiment(polarity=0.0, subjectivity=0.0)
# Rückruf: Rossmann warnt vor Metallsplittern in diesen Maiswaffeln - Heilpraxisnet.de
# Sentiment(polarity=0.0, subjectivity=0.0)
# Alimentar pollos de forma remota es posible con Lightning Network - CriptoNoticias
# Sentiment(polarity=0.0, subjectivity=0.0)
# Hacemos las maletas con Montblanc y BMW. - loff.it
# Sentiment(polarity=0.0, subjectivity=0.0)
# Less pressure seen on Asia currencies as US Fed takes more dovish stance - Philippine Star
# Sentiment(polarity=0.16666666666666669, subjectivity=0.2833333333333333)
# Apple closes two Dallas stores in apparent bid to ward off patent trolls - Ars Technica
# Sentiment(polarity=0.05, subjectivity=0.35)
# Social Security expansion bill poised to gain traction in Congress - CNBC
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# 起底银漫矿业：今年近5亿业绩承诺被上市公司视为主力_重组 - 搜狐
# Sentiment(polarity=0.0, subjectivity=0.0)
# Hurdalıktan Çıkarılıp Yeniden Hayata Döndürülen 7 'Eski' Otomobil - Webtekno
# Sentiment(polarity=0.0, subjectivity=0.0)
# Altının gram fiyatı 7 haftanın zirvesini gördü - Memurlar
# Sentiment(polarity=0.0, subjectivity=0.0)
# 巴菲特致股東信「最全整理」：不再公布每股帳面價值、股價貴不適合庫藏 - 鉅亨網
# Sentiment(polarity=0.0, subjectivity=0.0)
# F1-es technikát kap a felfrissített Volvo XC90 - TotalCar
# Sentiment(polarity=0.0, subjectivity=0.0)
# Lidl issues an urgent recall notice over salt and pepper grinders that could contain GLASS - Daily Mail
# Sentiment(polarity=0.0, subjectivity=0.0)
# Vendido en Donostia el 12541, primer premio de la Lotería Nacional. - Noticias de Gipuzkoa
# Sentiment(polarity=0.0, subjectivity=0.0)
# Marijnissen: stembusgang 20 maart wordt Rutte-referendum - NOS
# Sentiment(polarity=0.0, subjectivity=0.0)
# France's Societe Generale to cut 1,500 jobs - Rappler
# Sentiment(polarity=0.0, subjectivity=0.0)
# Баффетт пообещал гигантское приобретение после финансовых потерь - РБК
# Sentiment(polarity=0.0, subjectivity=0.0)
# Viaja al espacio la primera pasajera a bordo de un vuelo comercial - RT en Español
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kraft Heinz writedown hits Warren Buffett’s Berkshire Hathaway results - Financial Times
# Sentiment(polarity=0.0, subjectivity=0.0)
# BDO: Tendencias tecnológicas para las empresas durante 2019 - iProUp
# Sentiment(polarity=0.0, subjectivity=0.0)
# Estados Unidos, China y la “cortina de gigabytes” - Periodismo.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# John McAfee Blows His Own Horn Over Bitcoin Price Predictions - CCN
# Sentiment(polarity=0.6, subjectivity=1.0)
# クアルコム社長「Snapdragon 855の5Gスマホ、初投入はOPPOから」 #MWC2019 - Engadget 日本版
# Sentiment(polarity=0.0, subjectivity=0.0)
# El perfil financiero de la Generación Z: digitales, planificados y ahorradores - AméricaEconomía.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Superbelegger Buffett raakt $100 miljard niet kwijt - Telegraaf.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Salesforce, Dell and 8 other top tech companies hiring remote workers now - CNBC
# Sentiment(polarity=0.09166666666666667, subjectivity=0.35833333333333334)
# Derivatives Giant Fidelity Investments Receives and Passes on the Lightning Torch - Cointelegraph
# Sentiment(polarity=0.0, subjectivity=1.0)
# Relojes inteligentes para abrir las puertas y encender el motor de tu vehículo - iProUp
# Sentiment(polarity=0.0, subjectivity=0.0)
# 巴菲特致股东信：重点关注市场价格 - 新京报
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mau Akuisisi Bank Kecil, BCA: Namanya Kita Nggak Sebut Dulu - detikFinance
# Sentiment(polarity=0.0, subjectivity=0.0)
# Warren Buffett’s Letter To Berkshire Hathaway Shareholders: Highlights - BloombergQuint
# Sentiment(polarity=0.0, subjectivity=0.0)
# ปณท โชว์มาตรฐานส่งอีเอ็มเอส ช่วงเช้าจากกทม. ปลายทางกทม. ถึงผู้รับในวันเดียว - ข่าวสด
# Sentiment(polarity=0.0, subjectivity=0.0)
# Petrobras dá início ao terceiro FPSO de Búzios - O Petróleo
# Sentiment(polarity=0.0, subjectivity=0.0)
# How Lowe's CEO Marvin Ellison went from making $4.35 an hour as a Target security guard to running the second biggest home-improvement retailer in the US - Business Insider
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ekonomiści ostrzegają: realizacja obietnic PiS zamknie drogę do wyższego ratingu Polski - BusinessInsider
# Sentiment(polarity=0.0, subjectivity=0.0)
# Cette idée de la N-VA repousserait encore davantage la sortie du nucléaire - lalibre.be
# Sentiment(polarity=0.0, subjectivity=0.0)
# Here are the stocks Warren Buffett says he's betting on for the long run - CNBC
# Sentiment(polarity=-0.05, subjectivity=0.4)
# KPMG: Norge er blant landene i verden som er best forberedt på selvkjørende biler - E24
# Sentiment(polarity=1.0, subjectivity=0.3)
# Personeel Intertoys Zwolle bekogeld door boze klanten | Binnenland - AD.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Microsoft staff: Do not use HoloLens for war - BBC News
# Sentiment(polarity=0.0, subjectivity=0.0)
# OKEx Lists XRP and Bitcoin Cash (BCH) on its Customer-to-Customer Market - Ethereum World News
# Sentiment(polarity=0.0, subjectivity=0.0)
# CEO Coinbase рассказал, куда могли исчезнуть деньги биткоин-биржи QuadrigaCX и связано ли это со смертью ее основателя - http://forklog.com/
# Sentiment(polarity=0.0, subjectivity=0.0)
# La prima vera turista spaziale su Virgin Galactic: “E' stato intenso e magico” - La Stampa
# Sentiment(polarity=0.0, subjectivity=0.0)
# Paketjätten UPS stoppar utlämning i Rosengård - Expressen
# Sentiment(polarity=0.0, subjectivity=0.0)
# Airbus: Weniger Gehalt für den neuen Chef - WELT
# Sentiment(polarity=0.0, subjectivity=0.0)
# Stocks To Watch: Food For Thought - Seeking Alpha
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mega Millions results for 02/22/19; $1 million winner sold in Michigan - MLive.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Elon Musk's tweets show that Tesla's revamped board is still bad at its job — and it could get the company into even more trouble - Business Insider
# Sentiment(polarity=-0.13333333333333328, subjectivity=0.4555555555555555)
# A 97-Year-Old Tycoon, His 4 Wives And The Push To Revive A Casino Empire - NDTV News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Axis Bank Revises Fixed Deposit (FD) Interest Rates; What Other Lenders Offer - NDTV News
# Sentiment(polarity=-0.012499999999999997, subjectivity=0.2875)
# Nytt datasystem samler kraftbransjen: Slik påvirkes din strømregning - E24
# Sentiment(polarity=0.0, subjectivity=0.0)
# Fusión Embraer Boeing: Corte de Brasil ordena suspender negociaciones - Cambio16
# Sentiment(polarity=0.0, subjectivity=0.0)
# Oppo 公佈更多10 倍混合光學變焦技術的細節 - Engadget 中文版
# Sentiment(polarity=0.0, subjectivity=0.0)
# Oppo 公佈更多10 倍混合光學變焦技術的細節 - Engadget 中文版
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bankalar Birliği'nden IMF açıklaması! - Haber7
# Sentiment(polarity=0.0, subjectivity=0.0)
# Campaigner Wilders ontwaakt door nieuwe rivaliteit op rechts; afwachten is voor de PVV geen optie meer - Volkskrant
# Sentiment(polarity=0.0, subjectivity=0.0)
# The CEO of the world's largest cruise company reveals the advice he would give to his 25-year-old self - Business Insider
# Sentiment(polarity=0.0, subjectivity=0.0)
# Investeringsoraklets jakt fortsätter: ”Priserna är skyhöga” - Dagens Industri
# Sentiment(polarity=0.0, subjectivity=0.0)
# Additional RCom shares pledged with Axis Trustee - Moneycontrol.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Delight as HMV reopens at Merry Hill shopping centre - expressandstar.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# באפט למשקיעים: מעונין לבצע רכישה "בגודל פיל", אך המחירים גבוהים מדי - ynet ידיעות אחרונות
# Sentiment(polarity=0.0, subjectivity=0.0)
# Las redes 5G llegan este año a EEUU, pero tardarán en hacerlo a Latinoamérica - El Nuevo Herald
# Sentiment(polarity=0.0, subjectivity=0.0)
# 휘발유·경유 넉 달 만에 하락세 중단...국제유가 상승 영향 - YTN
# Sentiment(polarity=0.0, subjectivity=0.0)
# TUI-topman: Vliegen te goedkoop? Tja, dat is marktwerking - AD.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Wie Anleger den Brexit möglichst ungeschoren überstehen - derStandard.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# 48 ezer tudós kéri: állítsák le az 5G bevezetését, mert ez így egy „emberkísérlet” - hvg.hu
# Sentiment(polarity=0.0, subjectivity=0.0)
# Os automóveis elétricos mais vendidos em Portugal em janeiro - Jornal de Negócios - Portugal
# Sentiment(polarity=0.0, subjectivity=0.0)
# Aston Martin'in yeni modeli Project 003 görücüye çıkıyor! Yalnızca 500 tane üretilecek - Mynet
# Sentiment(polarity=0.0, subjectivity=0.0)
# La société générale envisagerait de supprimer 1.500 postes, dont 700 en France - 20 Minutes
# Sentiment(polarity=0.0, subjectivity=0.0)
# مركبة "فيرجن غالاكتيك" تتخطى حدود الفضاء - Sharjah24
# Sentiment(polarity=0.0, subjectivity=0.0)
# OPPO 10倍混合光学变焦技术发布：新机Q2亮相-OPPO,光学变焦, ——快科技(原驱动之家)--科技改变未来 - 驱动之家
# Sentiment(polarity=0.0, subjectivity=0.0)
# 30周年のマツダ ロードスター、レストアサービス受け入れ強化検討…ノスタルジック2デイズ2019 - レスポンス
# Sentiment(polarity=0.0, subjectivity=0.0)
# בגלל ההחזקות בקראפט היינץ: הפסד של 25 מיליארד ד' לחברה של באפט ברבעון הרביעי - TheMarker
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mercedes-Benz: Daimlers neues Elektroauto EQC verzögert sich - Golem.de - Golem.de
# Sentiment(polarity=0.0, subjectivity=0.0)
# Evan Williams: Mitbegründer verlässt Twitter - heise online
# Sentiment(polarity=0.0, subjectivity=0.0)
# خبراء يحذرون: الاقتصاد العالمي يتجه إلى المصير "المخيف" - سكاي نيوز عربية
# Sentiment(polarity=0.0, subjectivity=0.0)
# Texas Crypto Fund Unveils Two New Ways to Value Bitcoin - CCN
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# 直击|继裁员后滴滴将在2月25日起减少员工各项福利 - 新浪网
# Sentiment(polarity=0.0, subjectivity=0.0)
# Former Enron CEO released after 12 years in prison - ABS-CBN News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Fca, nel 2018 a Marchionne stipendio da 11 milioni di... - FormulaPassion.it
# Sentiment(polarity=0.0, subjectivity=0.0)
# Volvo XC90 2019: la clave es la tecnología - SoyMotor.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Buffett holds out hope for giant deal as cash pile grows again - BNNBloomberg.ca
# Sentiment(polarity=0.0, subjectivity=1.0)
# Buffett holds out hope for giant deal as cash pile grows again - BNNBloomberg.ca
# Sentiment(polarity=0.0, subjectivity=1.0)
# Les Américains boudent la malbouffe et font plonger les résultats des industriels - Sud Ouest
# Sentiment(polarity=0.0, subjectivity=0.0)
# Social Security: 7 Smart Ways to Get More Benefits - The Motley Fool
# Sentiment(polarity=0.33690476190476193, subjectivity=0.5273809523809524)
# Cómo es el ranking de las marcas de autos más confiables en el mercado norteamericano - Infobae.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# CasperLabs planea desarrollar una nueva blockchain basada en PoS con la ayuda de Vlad Zamfir - CoinCrispy
# Sentiment(polarity=0.0, subjectivity=0.0)
# Warren Buffett wants to make an 'elephant-sized' purchase, but says 'prices are sky-high' - CNBC
# Sentiment(polarity=0.2, subjectivity=0.1)
# Buffett med ketchupsmell – dette skriver investorlegenden i sitt årlige brev til aksjonærene - Dagens Næringsliv
# Sentiment(polarity=0.0, subjectivity=0.0)
# Argentina: Cotización del dólar hoy sábado 23 de febrero del 2019, según BNA - LaRepublica.pe
# Sentiment(polarity=0.0, subjectivity=0.0)
# La Société Générale envisage 1.500 suppressions de postes - FRANCE 24
# Sentiment(polarity=0.0, subjectivity=0.0)
# Son Dakika: 23 Şubat güncel Altın fiyatları ne kadar? Gram altın, çeyrek altın fiyatları... - Habertürk
# Sentiment(polarity=0.0, subjectivity=0.0)
# De gör om – innan nya gäster ska in - VästerviksTidningen
# Sentiment(polarity=0.0, subjectivity=0.0)
# Royal Enfield Classic 350 ABS White launch price Rs 1.53 L - Video walkaround - RushLane
# Sentiment(polarity=0.08333333333333333, subjectivity=0.08333333333333333)
# Deze auto heeft de eeuwige jeugd | Auto - AD.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Parníky IKEA na dálkové ovládání odstraňují odpadky z londýnské řeky - Živě.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# El primer deportivo híbrido de Lamborghini podría estar en Frankfurt - Yahoo Finanzas España
# Sentiment(polarity=0.0, subjectivity=0.0)
# Maloobchodním prodejcům kralují korporace z USA, nejlepším nováčkem žebříčku je Metro - E15.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ajit Pai says broadband access is soaring—and that he’s the one to thank - WIRED
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tahminleri Tutan Uzmanın Bitcoin Yorumu! Son Dakika Ripple Haberleri - Kripto Koin
# Sentiment(polarity=0.0, subjectivity=0.0)
# "أبل" بصدد طرح بطاقة ائتمانية... تعرف إلى امتيازاتها - Sputnik Arabic
# Sentiment(polarity=0.0, subjectivity=0.0)
# Streit um Preiserhöhung: Kein Heinz-Ketchup mehr bei Edeka - t-online.de
# Sentiment(polarity=0.0, subjectivity=0.0)
# Daftar Harga Paket Wisata Kapal Pesiar di Astindo Travel Fair 2019 - KOMPAS.com
# Sentiment(polarity=0.7, subjectivity=0.9)
# Τα «πώς» και τα «γιατί» της ψηφιακής ταυτότητας - TVXS - TV Χωρίς Σύνορα
# Sentiment(polarity=0.0, subjectivity=0.0)
# «Свиномобиль»: Состояние пикапа УАЗ «Патриот» с пробегом поразило сеть - РИА "VladTime"
# Sentiment(polarity=0.0, subjectivity=0.0)
# Still gambling on the National Lottery? Here's a far more likely route to riches - Motley Fool UK
# Sentiment(polarity=0.3, subjectivity=0.85)
# كاميرا سرية تثير التساؤل: هل تتجسس شركات الطيران على الركاب؟ - سكاي نيوز عربية
# Sentiment(polarity=0.0, subjectivity=0.0)
# كاميرا سرية تثير التساؤل: هل تتجسس شركات الطيران على الركاب؟ - سكاي نيوز عربية
# Sentiment(polarity=0.0, subjectivity=0.0)
# كاميرا سرية تثير التساؤل: هل تتجسس شركات الطيران على الركاب؟ - سكاي نيوز عربية
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bransons Raumgleiter erreicht weiteres Mal Weltall - Krone.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# 一二线城市二手房价1月环比均跌0.1% - 人民网
# Sentiment(polarity=0.0, subjectivity=0.0)
# EL BCE prevé un crecimiento económico más débil y prepara más liquidez - Investing.com España
# Sentiment(polarity=0.0, subjectivity=0.0)
# Microsoft workers protest use of HoloLens headsets for war: "We did not sign up to develop weapons" - CBS News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bitcoin-Betrug auf Telegram und Reddit: So wird Kryptowährung erbeutet - SPIEGEL ONLINE
# Sentiment(polarity=0.0, subjectivity=0.0)
# مساهمو جت إيروايز الهندية يوافقون على مبادلة ديون بأسهم - euronews
# Sentiment(polarity=0.0, subjectivity=0.0)
# Draft e-commerce policy: Government mandates etailers to register entity in India - Moneycontrol.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# มะเร็ง : ชายอเมริกันเขียนประกาศข่าวมรณกรรมตัวเอง เตือนใจผู้คนถึงพิษภัยบุหรี่ - บีบีซีไทย
# Sentiment(polarity=0.0, subjectivity=0.0)
# 【誤導買家】中國擬廢建築面積 中國網民斥「都是李嘉誠搞出來」 - 雅虎香港新聞
# Sentiment(polarity=0.0, subjectivity=0.0)
# 张勇：阿里巴巴不会裁员 - 联合早报
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kodeks pracy 2019. URLOPY będą dłuższe? Urlop rodzicielski, wypoczynkowy i na żądanie do zmiany [23.02.2019 r.] - Nowa Trybuna Opolska
# Sentiment(polarity=0.0, subjectivity=0.0)
# СМИ: новая разработка АвтоВАЗа поступит в продажу в конце года - URA.Ru
# Sentiment(polarity=0.0, subjectivity=0.0)
# Volkswagen Multivan T6: ligero restyling y versión eléctrica - SoyMotor.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Top business leaders unite to address Brain Drain; plan for world-class tech university - Economic Times
# Sentiment(polarity=0.35, subjectivity=0.35)
# The 34 best under-the-radar beauty products, according to INSIDER employees - INSIDER
# Sentiment(polarity=1.0, subjectivity=0.3)
# HoloLens 2 could be launched at MWC19; dozens of Microsoft staff oppose its proposed military applications - Notebookcheck.net
# Sentiment(polarity=-0.1, subjectivity=0.1)
# 易会满对外“首秀”赴上海调研科创板强调好事办好 - 东方财富网
# Sentiment(polarity=0.0, subjectivity=0.0)
# Multinacional italiana anuncia fábrica com investimento de R$ 20 milhões no Sul de MG - G1
# Sentiment(polarity=0.0, subjectivity=0.0)
# Des employés de Microsoft protestent contre la militarisation de HoloLens - Gamekult
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ethereum'da uzun pozisyonlar fırladı, Kasım ayı tekrar mı edecek? - Uzman Coin
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nejrozšířenějším elektromobilem světa je Nissan Leaf - Novinky.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Desemprego bate recorde em metade das capitais brasileiras - Diário do Centro do Mundo
# Sentiment(polarity=0.0, subjectivity=0.0)
# الذهب يسجل ثاني أسبوع من المكاسب - النهار
# Sentiment(polarity=0.0, subjectivity=0.0)
# بعد خسارته 10 جنيهات.. ماذا فعلت أسعار الذهب في مصر اليوم؟ - مصراوي
# Sentiment(polarity=0.0, subjectivity=0.0)
# Las cinco grandes ausencias del MWC | Economía | Edición América - EFE - Noticias
# Sentiment(polarity=0.0, subjectivity=0.0)
# «Разбила все мифы в пух и прах»: Как Mazda CX-5 проявила себя в гонке с Mercedes-Benz ML 350 - РИА "VladTime"
# Sentiment(polarity=0.0, subjectivity=0.0)
# «Совсем другие ощущения»: Автовладелец пересел с Hyundai Solaris на Renault Megane и поделился впечатлениями - РИА "VladTime"
# Sentiment(polarity=0.0, subjectivity=0.0)
# Masz taki telefon? Jesteś na celowniku hakerów - fakt.pl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Após perder US$ 190 milhões, empresa de criptomoeda faz outra gafe absurda - TecMundo
# Sentiment(polarity=0.0, subjectivity=0.0)
# Cómo encontrar puntos de carga para el coche eléctrico - ComputerHoy
# Sentiment(polarity=0.0, subjectivity=0.0)
# Samsung kills Blu-ray players. Blame streaming, smart TVs and Apple - CNET
# Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# Ziraat Bankası'nda Demirören'e kredi açıklaması - Halktv
# Sentiment(polarity=0.0, subjectivity=0.0)
# Für Investmentfonds war der Jänner ein Frostmonat - derStandard.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# Más rápido y potente que nunca: nuevo Mini John Cooper Works GP - Diario de Colmenar Viejo
# Sentiment(polarity=0.0, subjectivity=0.0)
# IRCTC SBI Platinum Card Offers Discount, Cashback On Ticket Bookings: 10 Things To Know - NDTV News
# Sentiment(polarity=0.1, subjectivity=0.0)
# Il Bitcoin? Sottovalutato del 50% - Money.it
# Sentiment(polarity=0.0, subjectivity=0.0)
# Alerta utilizadores do iPhone/iPad! Remova já estas Apps - Pplware
# Sentiment(polarity=0.0, subjectivity=0.0)
# โรงงานยาสูบฯ มีแผนเล็งขายกัญชา กัญชง รับขึ้นภาษีบุหรี่ ต.ค.นี้ - ไทยรัฐ
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sorteo de Euromillones deja más de 366.000 euros en Alsasua, 22 de febrero | Sociedad | EiTB - EiTB Radio Televisión Pública Vasca
# Sentiment(polarity=0.0, subjectivity=0.0)
# هواوي: شبكات الجيل الخامس ليست قنبلة ذرية بالتأكيد - البوابة العربية للأخبار التقنية AITnews
# Sentiment(polarity=0.0, subjectivity=0.0)
# Αναδρομικά: Πώς θα κλειδώσουν οι τελικές αποφάσεις | ενότητες, οικονομία - Real.gr
# Sentiment(polarity=0.0, subjectivity=0.0)
# هواوي: شبكات الجيل الخامس ليست قنبلة ذرية بالتأكيد - البوابة العربية للأخبار التقنية AITnews
# Sentiment(polarity=0.0, subjectivity=0.0)
# WhatsApp-Phishing: E-Mail gaukelt auslaufendes WhatsApp-Abo vor - t-online.de
# Sentiment(polarity=0.0, subjectivity=0.0)
# Avance de negociaciones EE.UU./China, vital para mejorar expectativas de expansión mundial - MercoPress
# Sentiment(polarity=0.1, subjectivity=0.4)
# La demora del peritaje sobre el Popular frena una causa pendiente de pruebas - Yahoo Finanzas España
# Sentiment(polarity=0.6, subjectivity=0.9)
# Muffin Break Boss Slams Millennials Because They Won't Work For Free - Pedestrian TV
# Sentiment(polarity=0.4, subjectivity=0.8)
# Rekordstort bekämpningsområde för granbarkborre - ATL - Lantbrukets affärstidning
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mega-Sena: concurso 2127 de hoje pode pagar R$ 37 milhões - Mais Minas
# Sentiment(polarity=0.0, subjectivity=0.0)
# Jarosław Kaczyński przedstawił główne założenia nowego programu PiS | Z kraju - TVN24 BiS
# Sentiment(polarity=0.0, subjectivity=0.0)
# SPK'dan kaldıraçlı Bitcoin borsasına kapatma talebi - Uzman Coin
# Sentiment(polarity=0.0, subjectivity=0.0)
# تقرير صادم... "فيسبوك" يستحوذ على "معلومات حساسة" عنك دون علمك - Sputnik Arabic
# Sentiment(polarity=0.0, subjectivity=0.0)
# Pace fiscale 2019: scadenza domanda e modulo. Come fare la pratica - Termometro Politico
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tcash Tunda Konversi, LinkAja Tatap Optimis Gerakan Non-Tunai - Detikcom
# Sentiment(polarity=0.0, subjectivity=0.0)
# 'Studenten Amsterdam voelen zich onveilig' | Binnenland - Telegraaf.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ex-Novartis-Chef Vasella tritt aus Schweizergarde-Stiftung aus - BLICK.CH
# Sentiment(polarity=0.0, subjectivity=0.0)
# لادا تخفض أسعار "جرانتا" موديل 2019 في مصر.. تعرف على السعر الجديد - مصراوي
# Sentiment(polarity=0.0, subjectivity=0.0)
# 華碩新手機ZenFone 6型號確定5月發表 - SOGI 手機王
# Sentiment(polarity=0.0, subjectivity=0.0)
# موظفون في مايكروسوفت يطالبون الشركة بإلغاء تعاقد مع الجيش الأمريكي - رويترز العربية
# Sentiment(polarity=0.0, subjectivity=0.0)
# YouTube elimina más de 400 canales tras la sangría de anunciantes - TreceBits
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bonus mobili, ecco quando abbiamo diritto allo sconto (e quando invece viene negato) - Today
# Sentiment(polarity=0.0, subjectivity=0.0)
# Stefan Löfven starkt kritisk mot Swedbanks penningtvättarbete - Dagens Nyheter
# Sentiment(polarity=0.0, subjectivity=0.0)
# «Κόκκινη κάρτα» στις πλαστικές σακούλες βγάζει η Κύπρος - iefimerida
# Sentiment(polarity=0.0, subjectivity=0.0)
# Volkswagen Multivan : le Combi passe à l’électrique en 2019 - Automobile Propre
# Sentiment(polarity=0.0, subjectivity=0.0)
# Volkswagen Multivan : le Combi passe à l’électrique en 2019 - Automobile Propre
# Sentiment(polarity=0.0, subjectivity=0.0)
# West Aussie picks up $670k Lotto win - The West Australian
# Sentiment(polarity=0.4, subjectivity=0.2)
# Next recession: Fed signal tells Wall Street that crisis is nearing - Business Insider
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kia se rue sur l’électrique : les contours d’un nouveau modèle teasé avant Genève - Clubic.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# 508'in yolundan giden Yeni Peugeot 208 ortaya çıktı! - ShiftDelete.Net
# Sentiment(polarity=0.0, subjectivity=0.0)
# Prokuratura: 'Z Gant Development wyprowadzono 650 mln zł'. Zatrzymano kolejne trzy osoby - Wroclaw.Wyborcza.pl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Elon Musk’s and Jack Dorsey’s recent comment on Bitcoin – what it might mean - The Financial Express
# Sentiment(polarity=-0.10416666666666667, subjectivity=0.3125)
# Nederlandse economie is 'stabiel' en behoudt hoogste kredietstatus - NU.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kabaty: zamiast wielkiego Tesco będą mieszkania i mniejszy sklep? - Warszawa.Wyborcza.pl
# Sentiment(polarity=0.0, subjectivity=0.0)
# İşte CUPRA markasının ilk özgün çalışması "Formentor" - LOG - log
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bridgestone Blizzak LM005: la prova dei nuovi pneumatici invernali - HDmotori
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bagage cabine payant : Ryanair et Wizz Air condammées en Italie - Air-Journal
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bagage cabine payant : Ryanair et Wizz Air condammées en Italie - Air-Journal
# Sentiment(polarity=0.0, subjectivity=0.0)
# Intel 的5G modem 要到2020 年才會出現在手機之上 - Engadget 中文版
# Sentiment(polarity=0.0, subjectivity=0.0)
# NuConta vale a pena? Saiba como funciona a conta digital do Nubank - TechTudo
# Sentiment(polarity=0.0, subjectivity=0.0)
# Huawei Mate X 摺芒外翻式設計MWC 2019 官方會場佈置搶先流出 - 香港01
# Sentiment(polarity=0.0, subjectivity=0.0)
# Medmrežje tarča napadov, kot jih še ni bilo - RTV Slovenija
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ex-SA cricket star accused of being a thief and fraudster by business partner | Weekend Argus - IOL
# Sentiment(polarity=0.0, subjectivity=0.0)
# New York's dance with Amazon shows us how to fight for a city's future - The Guardian
# Sentiment(polarity=0.06818181818181818, subjectivity=0.2897727272727273)
# Acciona se adjudica la eficiencia de 400 edificios de Madrid por 17 millones - Investing.com España
# Sentiment(polarity=0.0, subjectivity=0.0)
# Vegan Creme Egg 'Tastes Better Than The Original' - Plant Based News
# Sentiment(polarity=0.4375, subjectivity=0.625)
# La production de Nutella va reprendre près de Rouen après un arrêt de plusieurs jours - France 3 Régions
# Sentiment(polarity=0.0, subjectivity=0.0)
# 阳哥理财；黄金下周下探回升，原油还有上涨空间_名家点金 - 中金在线
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sky TV update - As prices set to rise there's an ultimate deal that will cut your bill - Express
# Sentiment(polarity=0.0, subjectivity=1.0)
# Viber начнёт взимать с владельцев чат-ботов от $4500 в месяц - vc.ru
# Sentiment(polarity=0.0, subjectivity=0.0)
# L'allemand Heidelberg réduit sa part dans le capital de Ciments du Maroc - Le360.ma
# Sentiment(polarity=0.0, subjectivity=0.0)
# คพ.พบรถบรรทุกควันดำในกทม.1274 คัน - เดลีนีวส์
# Sentiment(polarity=0.0, subjectivity=0.0)
# Stellar Price Forecast 2019 – At Breakneck Speed to $1 and Higher. Expert Opinions and Arguments - U.Today
# Sentiment(polarity=0.25, subjectivity=0.375)
# Bitcoin [BTC] worth $300,000 stolen by scammers in email-based “Sextortion” racket - AMBCrypto News
# Sentiment(polarity=0.3, subjectivity=0.1)
# Bitcoin [BTC] worth $300,000 stolen by scammers in email-based “Sextortion” racket - AMBCrypto News
# Sentiment(polarity=0.3, subjectivity=0.1)
# Tesco likwiduje sklepy. Pełna lista przeznaczonych do zamknięcia - o2
# Sentiment(polarity=0.0, subjectivity=0.0)
# La furgoneta Nissan e-NV200 bate su récord de matriculaciones en España - El Mercantil
# Sentiment(polarity=0.0, subjectivity=0.0)
# À Wall Street, le Dow Jones en hausse pour la 9e semaine de suite - Le Courrier du Vietnam
# Sentiment(polarity=0.0, subjectivity=0.0)
# Updated 2019 Maruti Suzuki Ignis Spotted At Dealership Yard - Car and Bike
# Sentiment(polarity=0.0, subjectivity=0.0)
# 「お辞儀ハンコ」日本にはびこる謎のビジネスマナー（LIMO） - Yahoo!ニュース
# Sentiment(polarity=0.0, subjectivity=0.0)
# Daimler i BMW zainwestują 1,13 mld dolarów w spółkę, która ma konkurować z Uberem - BusinessInsider
# Sentiment(polarity=0.0, subjectivity=0.0)
# AutoSpace - Best of the Week: Bentley Accident in Delhi, 2019 Ford Endeavour Launch & More - News18
# Sentiment(polarity=0.75, subjectivity=0.4)
# Κτηματολόγιο: Τα 15 SOS για να μη χάσετε τα ακίνητά σας - aftodioikisi.gr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Как предотвратить появление сколов на крышке багажника, поделился владелец LADA Granta 2018 - РИА "VladTime"
# Sentiment(polarity=0.0, subjectivity=0.0)
# Des sénateurs US interrogent Sanofi et d'autres sur l'insuline - Boursorama
# Sentiment(polarity=0.0, subjectivity=0.0)
# «Вот это жгут»: Mitsubishi Pajero Sport и LADA Niva сразились на бездорожье - РИА "VladTime"
# Sentiment(polarity=0.0, subjectivity=0.0)
# 〈全民退休投資實驗〉名額僅限萬人這種人最適合參加 - 鉅亨網
# Sentiment(polarity=0.0, subjectivity=0.0)
# Το πυραυλοκίνητο αεροπλάνο της Virgin Galactic πέταξε στα σύνορα του διαστήματος μεταφέροντας επιβάτη - Capital.gr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Creval, chi sono i putiniani di Altera che trottano nel Credito Valtellinese (con i vertici in bilico) - Startmag Web magazine
# Sentiment(polarity=0.0, subjectivity=0.0)
# Para el 2020 se podrá dormir mientras el coche conduce, dice CEO de Tesla - Diario Gestión
# Sentiment(polarity=0.0, subjectivity=0.0)
# Keren Juga Nih, All New Nissan Livina Dimodif Racing Pakai Livery Advan - Semua Halaman - GridOto.com
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Twitter co-founder Ev Williams bids the company's board farewell - Engadget
# Sentiment(polarity=0.0, subjectivity=0.0)
# 为什么说现在真的很像2014年牛市前夜？ - 华尔街见闻
# Sentiment(polarity=0.0, subjectivity=0.0)
# 靠粗工起家的飲料王國 「綠洲策略」攻進70國 - 中時電子報
# Sentiment(polarity=0.0, subjectivity=0.0)
# Virgin Galactic takes first human passenger into space (VIDEOS) - RT
# Sentiment(polarity=0.125, subjectivity=0.21666666666666667)
# Cibercrimen a golpe de clic - EFE futuro
# Sentiment(polarity=0.0, subjectivity=0.0)
# Rating für Italien: Der Ausblick von Fitch bleibt negativ - Kleine Zeitung
# Sentiment(polarity=0.0, subjectivity=0.0)
# 2018 年台積電最大市場仍來自美國，中國市場虧損台幣28.18 億元 - 科技新報 TechNews
# Sentiment(polarity=0.0, subjectivity=0.0)
# Stefan Löfven ryter ifrån mot Swedbank - Expressen
# Sentiment(polarity=0.0, subjectivity=0.0)
# De meest interessante aftrekposten voor je belastingaangifte 2018 - Business Insider
# Sentiment(polarity=0.0, subjectivity=0.0)
# El escándalo de pedofilia que afecta a YouTube - MDZ Online
# Sentiment(polarity=0.0, subjectivity=0.0)
# GIS wycofuje ze sprzedaży wafle kukurydziane. Mogą zawierać fragmenty metalu - rmf24.pl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Penny: Ekel-Fund in Produkt - Kunde völlig perplex | Wirtschaft - Merkur.de
# Sentiment(polarity=0.0, subjectivity=0.0)
# 'เวอร์จินกาแล็คติก'ทดสอบ เครื่องบินท่องอวกาศครั้งที่2 - เดลีนีวส์
# Sentiment(polarity=0.0, subjectivity=0.0)
# Gold Prices Rise By Rs 90 On Strong Global Cues: 5 Things To Know - NDTV News
# Sentiment(polarity=0.21666666666666665, subjectivity=0.36666666666666664)
# Tata 45X production variant is ALTROZ - Trademark filings confirm - RushLane
# Sentiment(polarity=0.0, subjectivity=0.0)
# Marokkanen participeren nog altijd niet zo goed in arbeid - ThePostOnline
# Sentiment(polarity=0.0, subjectivity=0.0)
# Deretan Modifikasi Xpander, Bisa Jadi Inspirasi Ubah All New Nissan Livina - Semua Halaman - GridOto.com
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# L'ancien PDG d'Enron libéré après douze ans de prison - Paris Match
# Sentiment(polarity=0.0, subjectivity=0.0)
# Apple ‘Project Titan’ Could Mean an Electric Van, Not a Multi-Billion Acquisition of Tesla - CCN
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
# เงินบาทกลับมาอ่อนค่าปลายสัปดาห์ หลังแข็งค่าสุดในรอบกว่า 5 ปี แต่หุ้นขึ้นตามปัจจัยต่างประเทศ - ข่าวสด
# Sentiment(polarity=0.0, subjectivity=0.0)
# ถอดสลักความคิด : AIS ACADEMY for THAIs: Intelligent Nation Series ตามทันเทคโนโลยี เพิ่มทักษะ ก่อเกิดวัฒนธรรม - Siamphone
# Sentiment(polarity=0.8, subjectivity=0.9)
# Muskatın fazlası tehlikeli! Afrodizyak etkiden halüsinasyona... - Posta
# Sentiment(polarity=0.0, subjectivity=0.0)
# Conoce el valor de tu coche en el mercado - El Mundo Financiero
# Sentiment(polarity=0.0, subjectivity=0.0)
# El uso de la factura electrónica creció un 14.9% en 2018 - El Mundo Financiero
# Sentiment(polarity=0.0, subjectivity=0.0)
# Rapapolvos de la Audiencia Provincial de Barcelona al Banco Popular - El Mundo Financiero
# Sentiment(polarity=0.6, subjectivity=0.9)
# Gobierno y empresas de energías renovables acuerdan prórrogas en Argentina - REVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# Hundreds of Southwest flights delayed - Honolulu Star-Advertiser
# Sentiment(polarity=0.0, subjectivity=0.0)
# Most and least affordable towns for first-time buyers revealed - Daily Mail
# Sentiment(polarity=0.06666666666666667, subjectivity=0.3)
# ‘Tectonic Shift’: CasperLabs Nabs Ethereum Developer Vlad Zamfir - CCN
# Sentiment(polarity=0.0, subjectivity=0.0)
# TCMB'nin 2018 karı 56,3 milyar liraya ulaştı - BLOOMBERG HT - BloombergHT
# Sentiment(polarity=0.0, subjectivity=0.0)
# KE ws. mięsa: od was zależy jak kontrolujecie produkty - Interia
# Sentiment(polarity=0.0, subjectivity=0.0)
# Baisse de l'indice des prix à la consommation - L'Économiste
# Sentiment(polarity=0.0, subjectivity=0.0)
# GBP Fundamental Forecast: Sterling Refuses to Believe in No Deal Brexit - DailyFX
# Sentiment(polarity=0.0, subjectivity=0.0)
# Audi e-tron изкатери ски писта (ВИДЕО) - Авто - Факти.БГ
# Sentiment(polarity=0.0, subjectivity=0.0)
# 再就職先はまさかの自販機!? 東京メトロ銀座線、引退した車両をリメイクした世界で1台だけの自販機を設置 - ねとらぼ
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tesla's terrible February 2019 does not bode well for the year - Quartz
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Rivian предложит «съёмную вспомогательную батарею» для электрического пикапа R1T - 3DNews
# Sentiment(polarity=0.0, subjectivity=0.0)
# El empleo en las plataformas de reparto: ¿colaboradores o asalariados? - Investing.com España
# Sentiment(polarity=0.0, subjectivity=0.0)
# 原油周评：油价企稳年内高位？警惕！多头上攻仍有隐患_外汇动态报道_汇通网www.fx678.com - 汇通网
# Sentiment(polarity=0.0, subjectivity=0.0)
# ZCash Company is Now the Electric Coin Company to Prevent Confusion - Ethereum World News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Erick Thohir Sebut Ekonomi RI Ranking 3 G20, Benarkah? - detikFinance
# Sentiment(polarity=0.0, subjectivity=0.0)
# Descartan una crisis en ITP Aero por el fin del Airbus A-380 - Deia
# Sentiment(polarity=0.0, subjectivity=0.0)
# Morrison government unveils energy plans - 9news.com.au
# Sentiment(polarity=0.0, subjectivity=0.0)
# Twitter-Mitbegründer Williams zieht sich von Spitze zurück - ORF.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# JR西日本227系1000番台、和歌山線を走る新型車両に試乗 - 展示会も - マイナビニュース
# Sentiment(polarity=0.0, subjectivity=0.0)
# Pr Ali Chebbi: "Notre politique monétaire entre instruments limités et objectifs implicites" - Espace Manager
# Sentiment(polarity=0.0, subjectivity=0.0)
# Komoly frissítést kapott a Volkswagen Transporter - TotalCar
# Sentiment(polarity=0.0, subjectivity=0.0)
# Dolandırıcılar sanal alemde v'olta' atıyor - ntv.com.tr
# Sentiment(polarity=0.0, subjectivity=0.0)
# 最近ホームレスを見かけることが少ない理由ー見えにくい住居不安定者の実態ー（藤田孝典） - Yahoo!ニュース - Yahoo!ニュース
# Sentiment(polarity=0.0, subjectivity=0.0)
# Karsan’dan ihracat atağı! - Sözcü
# Sentiment(polarity=0.0, subjectivity=0.0)
# Confesercenti: frenano i consumi, -3,6 miliardi di euro rispetto alle stime - TGCOM
# Sentiment(polarity=0.0, subjectivity=0.0)
# B.C. ticket holder wins Friday night's $25.9 million Lotto Max jackpot - Times Colonist
# Sentiment(polarity=0.3, subjectivity=0.2)
# B.C. ticket holder wins Friday night's $25.9 million Lotto Max jackpot - Times Colonist
# Sentiment(polarity=0.3, subjectivity=0.2)
# KE zwiększa pułap wsparcia dla rolników do 25 tys. euro - Interia
# Sentiment(polarity=0.0, subjectivity=0.0)
# '70 procent van de huurbemiddelaars rekent nog steeds illegale kosten' - NU.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Old Meets Young: Pension Funds and Crypto Investment - CoinDesk
# Sentiment(polarity=0.1, subjectivity=0.30000000000000004)
# 对标特斯拉Model 3 吉利GE11高清图曝光 - TOM
# Sentiment(polarity=0.0, subjectivity=0.0)
# Wee: Govt should standardise levy for permit extension beyond 10 years - Nation - The Star Online
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bollette, mini stangata in arrivo - Today
# Sentiment(polarity=0.0, subjectivity=0.0)
# Maxi multe, fallimenti e conti in difficoltà: così continua la crisi delle compagnie aeree low cost - Il Primato Nazionale
# Sentiment(polarity=0.0, subjectivity=0.3)
# A Surprise China Debt Default Upends Assumptions on Official Aid - Bloomberg
# Sentiment(polarity=0.0, subjectivity=0.0)
# ‘Türkiye’nin Otomobili’ için ortak çalışmalar başladı! - Sözcü
# Sentiment(polarity=0.0, subjectivity=0.0)
# Benelli To Introduce 502C Cruiser (HD Street 750 rival) In 2019 - GaadiWaadi.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Apple, Uygun Fiyatlı Cihaz Almak İsteyenler için "Yenilenmiş Ürün" Çözümü Sundu - Webtekno
# Sentiment(polarity=0.0, subjectivity=0.0)
# الخطوط الجوية الدولية الباكستانية تدشن رحلاتها إلى مطار العين الدولي - الإمارات اليوم
# Sentiment(polarity=0.0, subjectivity=0.0)
# Benarkah Jalanan Beton Lebih Cepat Buat Ban Jadi Botak? - Detikcom
# Sentiment(polarity=0.0, subjectivity=0.0)
# Smartphone-Revolution? Samsungs faltbares Handy ändert alles - derStandard.at
# Sentiment(polarity=0.6, subjectivity=0.9)
# 1-Penny-Übernahme: Flybe-Chefs setzten Aktionären Pistole auf die Brust - aeroTELEGRAPH
# Sentiment(polarity=0.0, subjectivity=0.0)
# 证监会处罚4宗内幕交易案件-新华网 - 新华网
# Sentiment(polarity=0.0, subjectivity=0.0)
# Alarm over hackersaanval op structuur van het internet - AD.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# ING: Vertrouwen beleggers stijgt voor het eerst in half jaar - NU.nl
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# S&P confirma calificaciones de AAAA1 del BID y sube su SACP a 'aaa' de a - PanamaOn
# Sentiment(polarity=0.0, subjectivity=0.0)
# Με χρυσό και λίρες συνελήφθη 55χρονος σε παράνομο ενεχυροδανειστήριο - Βρέθηκαν σπίτι του πανάκριβα ρολόγια - ΦΩΤΟ - www.enikos.gr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kivárásra játszó vásárlók keserítik az okostelefon-gyártók életét - Bitport
# Sentiment(polarity=0.0, subjectivity=0.0)
# Dirk valt Albert Heijn aan - Telegraaf.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# 四季度亏超30亿，股价反涨20%，最近的爱奇艺有点妖 - 每日经济新闻
# Sentiment(polarity=0.0, subjectivity=0.0)
# Inversionistas extranjeros son optimistas frente al mercado bursátil de China - Xinhua
# Sentiment(polarity=0.0, subjectivity=0.0)
# Minister waarschuwt: bevriezen AOW-leeftijd kost werkenden veel geld - RTL Nieuws
# Sentiment(polarity=0.0, subjectivity=0.0)
# YouTube nimmt Impfgegnern Werbeeinnahmen weg - futurezone.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# 逆风而行？ 英国脱欧最后期限逼近交易员却押注英镑下周飙涨至1.33 - 外汇宝
# Sentiment(polarity=0.0, subjectivity=0.0)
# Big W joins Coles targeting kids in giveaways - The West Australian
# Sentiment(polarity=0.0, subjectivity=0.05)
# Son dakika haberleri... Benzine gelen zamda son durum (22 Şubat 2019 Cuma İstanbul Ankara İzmir güncel benzin fiyatlarında son durum) - Ulusal Kanal
# Sentiment(polarity=0.0, subjectivity=0.0)
# Pace fiscale: il saldo e stralcio e la rottamazione ter - Corriere Salentino
# Sentiment(polarity=0.0, subjectivity=0.0)
# SciencesLes 8 plus gros avions jamais construits - Futura-Sciences
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tipo de cambio: Precio del euro a pesos mexicanos compra y venta hoy sábado 23 de febrero de 2019 - LaRepublica.pe
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4YFN reúne a las ‘startups’ más prometedoras del panorama mundial - EL PAÍS
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5G: todo listo para dar ya el siguiente salto - EL PAÍS
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tipo de cambio: Precio del dólar a pesos mexicanos para hoy sábado 23 de febrero de 2019 - LaRepublica.pe
# Sentiment(polarity=0.0, subjectivity=0.0)
# «МегаФон» закрыл свой проект в области телемедицины - РБК
# Sentiment(polarity=0.0, subjectivity=0.0)
# 初代プリウス発売から22年！ 増え続ける電動化車両の廃棄バッテリーの行方とは（WEB CARTOP） - Yahoo!ニュース
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nuevo Volvo XC90, ligeros retoques y nuevos motores con KERS - espíritu RACER
# Sentiment(polarity=0.0, subjectivity=0.0)
# ¿Qué es y en qué consiste la Inteligencia Aumentada? - ComputerHoy
# Sentiment(polarity=0.0, subjectivity=0.0)
# Under pressure: Inside an explosive week in the SNC-Lavalin controversy - CBC News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Der Brite, der in Wien allein einen Indie-Hit geschaffen hat - derStandard.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# Under pressure: Inside an explosive week in the SNC-Lavalin controversy - CBC News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Výnos 8500 procent za pět let. Hongkongská akcie vzbuzuje údiv, ale hlavně pochybnosti - E15.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Audi e-tron : prix à partir de 82 600 € - Caradisiac.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Call Center Tim, Wind, Tre e Vodafone: ecco le app per non essere truffato - TecnoAndroid
# Sentiment(polarity=-0.1, subjectivity=0.1)
# Sebi Bars Commodity Trading By Motilal Oswal, India Infoline In NSEL Case: Report - NDTV News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Var sjätte nallar pengar från barnen – kan vara olagligt - Dagens Industri
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tesla Model 3 來港展出！「跑車級」平民版電動車率先睇【附展覽資料】 - ezone.hk
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bill Maher urges Jeff Bezos, Amazon to bring jobs to red states, or they'll get 'angrier and crazier' - Fox News
# Sentiment(polarity=0.0, subjectivity=0.0)
# SEC Approves Access Bank’s Book Build For Proposed Green Bond Subscription - Leadership Newspaper
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.44999999999999996)
# ”Medhelps polisanmälan av Computer Sweden ett försök att flytta fokus” - Dagens Nyheter
# Sentiment(polarity=0.0, subjectivity=0.0)
# Siete claves para entender qué está pasando con Huawei - Yahoo Finanzas España
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kredietbeoordelaar Fitch stelt rating Italië niet bij, bezorgd over toekomst - NU.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Audi e-tron, yüzde 85 eğime tırmandı! - Sözcü
# Sentiment(polarity=0.0, subjectivity=0.0)
# 多位专家表示：货币政策未放松更非“大水漫灌” - 正义网
# Sentiment(polarity=0.0, subjectivity=0.0)
# La BRH veut connaitre l'impact des compagnies de transfert sur le change - Le Nouvelliste
# Sentiment(polarity=0.0, subjectivity=0.0)
# Staatssecretaris gaat volledig elektrisch rijden: 'Chauffeur heeft nog wat stress' - RTL Nieuws
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mahindra XUV300 boot space: Is it really TINY? [Video] - CarToq.com
# Sentiment(polarity=0.0, subjectivity=0.5)
# 【台熱爆遊戲】《還願》暗藏「小熊維尼習近平」遭強國抵制掀兩岸大駡戰 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# Syn Ferdinanda Piëcha vstupuje mezi výrobce automobilů s vlastní značkou - Auto.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Προβλήματα σε δρομολόγια του ΟΑΣΘ λόγω της χιονόπτωσης - Thestival
# Sentiment(polarity=0.0, subjectivity=0.0)
# Audi i Jaguar mají co dohánět, Tesla Model X jejich elektromobily zašlapal ve spotřebě do země - Hybrid.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Air New Zealand flight to Iran turned away due to lack of clearance - NEWS.com.au
# Sentiment(polarity=0.005681818181818177, subjectivity=0.4147727272727273)
# Качество или халтура? Владельцы поделились впечатлениями от Kia Rio X-Line - РИА "VladTime"
# Sentiment(polarity=0.0, subjectivity=0.0)
# Jeep Compass recalled in India over emission update - 11k SUVs affected - RushLane
# Sentiment(polarity=0.0, subjectivity=0.0)
# Uber is a massive success in South Africa - MyBroadband
# Sentiment(polarity=0.15, subjectivity=0.5)
# Probamos el Lexus UX 250h, un gran coche híbrido con un diseño interior más que discutible - Motorpasión
# Sentiment(polarity=0.0, subjectivity=0.0)
# Forget the National Lottery, EuroMillions, and Bitcoin – here's how I think you can get rich the easy way - Motley Fool UK
# Sentiment(polarity=0.4694444444444444, subjectivity=0.8277777777777778)
# 3500 liradan pahalı telefonun izahı yok - Posta
# Sentiment(polarity=0.0, subjectivity=0.0)
# Quanto vale la casa messa in vendita da Elon Musk - QuiFinanza
# Sentiment(polarity=0.0, subjectivity=0.0)
# La inteligencia artificial cuenta con un margen de error del 3% - Diario Siglo XXI
# Sentiment(polarity=-0.6, subjectivity=1.0)
# 黄金交易提醒：美国休市但黄金续刷新高两大因素暗示金价前景 - 东方财富网
# Sentiment(polarity=0.0, subjectivity=0.0)
# Έρευνα - μαχαιριά του ΙΟΒΕ: Το 64% των Ελλήνων μόλις που τα... - Newsit
# Sentiment(polarity=0.0, subjectivity=0.0)
# Pasokan Civic Type R ke Indonesia Aman - Kompas.com - KOMPAS.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# ホンダ英国工場撤退で大騒ぎの不思議 - Newsweekjapan
# Sentiment(polarity=0.0, subjectivity=0.0)
# Dacia a anuntat ofertele pentru Rabla 2019: Cat costa Logan, Sandero si Duster - Ziare.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# BP předpovídá nárůst roční výroby elektřiny z jádra na 3400 TWh do roku 2040 - oEnergetice.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Twitter: départ d'un de ses cofondateurs - AGEFI.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Биржа Huobi добавила поддержку токенов USDT на протоколе ERC-20 - http://forklog.com/
# Sentiment(polarity=0.0, subjectivity=0.0)
# أسعار الذهب تسجل ثاني أسبوع من المكاسب عالميًا - مصراوي
# Sentiment(polarity=0.0, subjectivity=0.0)
# 銀行衝房貸 鎖定優質客群 首購年利率跌破1.6% - Yahoo奇摩新聞
# Sentiment(polarity=0.0, subjectivity=0.0)
# Πώς θα γίνει η επένδυση-μαμούθ για το καζίνο στο Ελληνικό - Capital.gr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Yeni SsangYong Korando’dan İlk görüntüler geldi - Sözcü
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kia electrizará Ginebra con un nuevo concept car - PanamaOn
# Sentiment(polarity=0.0, subjectivity=0.0)
# Waspada Kebiasaan Taruh Telepon Genggam di Speedometer - KOMPAS.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# ChristenUnie: vluchten Lelystad Airport via IJsselmeer - NRC
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bu hafta parasını ona yatıran kazandı - Haber7
# Sentiment(polarity=0.0, subjectivity=0.0)
# BRIEFJE VAN JAN - Aan Mark Rutte - ThePostOnline
# Sentiment(polarity=0.0, subjectivity=0.0)
# Millenials trauen dubioser Asset-Klasse mehr als Aktien: Hier wiederholen sich die Fehler der 1996er-Anlegergeneration - Boerse-express.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Animal charities say Tesla's 'dog mode' is a nice idea, but you shouldn't use it - Business Insider
# Sentiment(polarity=0.6, subjectivity=1.0)
# easyJet proposera une liaison estivale Montpellier – Paris-CDG - Air-Journal
# Sentiment(polarity=0.0, subjectivity=0.0)
# Samsungs Falt-Smartphone: Wer zuletzt lacht, lacht am besten! - GIGA.de
# Sentiment(polarity=0.0, subjectivity=0.0)
# Schuhkonzern Humanic komplett an Financiers verpfändet - derStandard.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ce programme d'IA jugé trop dangereux pour être rendu public - 7sur7
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Veja recomendações para não perder suas economias ao realizar aplicações no mercado financeiro - Extra
# Sentiment(polarity=0.0, subjectivity=0.1)
# 2020 年蘋果A 系列處理器台積電獨家代工機率大，將採5 奈米製程 - 科技新報 TechNews
# Sentiment(polarity=0.0, subjectivity=0.0)
# Les meilleurs sites et applications pour télécharger des livres gratuitement - 01net.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Les meilleurs sites et applications pour télécharger des livres gratuitement - 01net.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# คาดหุ้นไทยสัปดาห์หน้าแกว่ง 1640 - 1685 จุด - thebangkokinsight.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Jet Airways, GoAir, SpiceJet Offer Discount On Flight Tickets, Details Here - NDTV News
# Sentiment(polarity=0.0, subjectivity=0.0)
# 美联储报告重申对利率政策保持耐心继续实施渐进式缩表计划 - 东方财富网
# Sentiment(polarity=0.0, subjectivity=0.0)
# Uber Black w Polsce od końca lutego. Wynajmiemy limuzynę przez aplikację - BusinessInsider
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.43333333333333335)
# Forfait Mobile : le forfait illimité Prixtel (jusqu’à 100 Go) à partir de 6,99€/mois - Presse-citron
# Sentiment(polarity=0.0, subjectivity=0.0)
# 大林組だけじゃない！就活女子狙う“卑劣手口” ＯＢ訪問アプリ悪用…会って肉体関係に発展→「業界に向いてない」（夕刊フジ） - Yahoo!ニュース
# Sentiment(polarity=0.0, subjectivity=0.0)
# รฟม.ซ้อมแผนฉุกเฉินรถไฟฟ้าติดค้าง - สำนักข่าว ไอเอ็นเอ็น
# Sentiment(polarity=0.0, subjectivity=0.0)
# أسعار العملات اليوم السبت 23-2-2019 - اليوم السابع
# Sentiment(polarity=0.0, subjectivity=0.0)
# أسعار العملات اليوم السبت 23-2-2019 - اليوم السابع
# Sentiment(polarity=0.0, subjectivity=0.0)
# TRAI to review mobile number portability charges even as monthly port requests decline - The Financial Express
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tim, la Borsa premia Inwit: debito giù con i tagli ai costi - ilGiornale.it
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ще достигне ли американският дълг 100% от БВП до края на десетилетието? - Investor.bg
# Sentiment(polarity=0.0, subjectivity=0.0)
# 시중에서 유통되는 5만원권 100조원 육박…유통 비중도 83.5%까지 치솟아 - 조선비즈
# Sentiment(polarity=0.0, subjectivity=0.0)
# Twitter co-founder Evan Williams leaving board - ABS-CBN News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Уорън Бъфет загуби $4.3 милиарда за един ден - Business.dir.bg
# Sentiment(polarity=0.0, subjectivity=0.0)
# Un titolo azionario interessante nel settore auto - Proiezioni di Borsa
# Sentiment(polarity=0.0, subjectivity=0.0)
# 亞鄰最低價限制！下周汽油估不漲、柴油估漲0.3元 - 蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# Soal Harga Sedan, Honda Masih Tunggu Harmonisasi Pajak - KOMPAS.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# 美股收高道指站上26000点道指和纳指均连涨九周_中国经济网——国家经济门户 - 中国经济网
# Sentiment(polarity=0.0, subjectivity=0.0)
# أميركا.. تراجع نشاط حفارات النفط لـ 3 أشهر متتالية - العربية نت
# Sentiment(polarity=0.0, subjectivity=0.0)
# 【新車速報】猛暴3缸超聚焦！Ford大改款Focus端出5大車型67.8萬元起！ - Yahoo奇摩汽車
# Sentiment(polarity=0.0, subjectivity=0.0)
# Στα 73,85 ευρώ, αλλά... για έναν μήνα η εισφορά σύνταξης στον ΕΦΚΑ - Ύπαιθρος Χώρα
# Sentiment(polarity=0.0, subjectivity=0.0)
# Le banche svizzere nuovo "obiettivo" delle Entrate - ilGiornale.it
# Sentiment(polarity=0.0, subjectivity=0.0)
# Илон Мъск взе колосален ипотечен кредит - Имоти - Факти.БГ
# ...
# Two punters share $13.6m Toto Hongbao prize money - The Straits Times
# Sentiment(polarity=0.0, subjectivity=0.0)
# Singtel engineers make first overseas 5G video call - The Straits Times
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Aktiespararnas vd kritisk både mot Swedbank och Finansinspektionen - Sveriges Television
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mais de R$ 3 milhões! Anatel multa Oi por reter receita da TIM - Tudocelular.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# -اتصالات-و-هواوي-تختبران-نقل-البيانات-عبر-الألياف-الضوئية-فائقة-السرعة - الاتحاد
# Sentiment(polarity=0.0, subjectivity=0.0)
# João Doria anuncia redução do aumento do preço médio do gás em São Paulo - A Tribuna
# Sentiment(polarity=0.0, subjectivity=0.0)
# Wall Street stärktes på positiva handelssignaler – livsmedelsjätten rasade - Dagens Industri
# Sentiment(polarity=0.0, subjectivity=0.0)
# Stát New York bude vyšetřovat Facebook kvůli datům uživatelů z aplikací - iDNES.cz
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Експерти: Надеждността никога не е била силната страна на Tesla - Dnes.bg
# Sentiment(polarity=0.0, subjectivity=0.0)
# Canadian cannabis LP #1 in TSX Venture 50's top performing companies - Daily Hive
# Sentiment(polarity=0.25, subjectivity=0.25)
# Avianca Colombia vai retirar aeronaves Embraer E190 da sua frota - Aeroflap
# Sentiment(polarity=0.0, subjectivity=0.0)
# Canadian cannabis LP #1 in TSX Venture 50's top performing companies - Daily Hive
# Sentiment(polarity=0.25, subjectivity=0.25)
# Facebook sabe hasta cuando estás en tus días, según el WSJ - Noticias - Nota - Azteca America
# Sentiment(polarity=0.0, subjectivity=0.0)
# NSE, others launch mutual funds platform to facilitate electronic transactions - The Eagle Online
# Sentiment(polarity=0.0, subjectivity=0.0)
# EuroMillions results: Friday's winning numbers for £14m jackpot and Thunderball - Manchester Evening News
# Sentiment(polarity=0.5, subjectivity=0.75)
# Affaire SNC-Lavalin: un scandale qui «soulève le problème de la corruption au Canada» - Sputnik France
# Sentiment(polarity=0.0, subjectivity=0.0)
# Spółka Warrena Buffetta przeceniona o 27% - Bankier
# Sentiment(polarity=0.0, subjectivity=0.0)
# Important way the 2008 financial crisis was worse than the Great Depression - New Zealand Herald
# Sentiment(polarity=0.18727272727272729, subjectivity=0.5609090909090909)
# Η «Μυτιληναίος» εξαγόρασε το 60% της Zeologic αντί 4 εκατ. ευρώ, της Χρύσας Λιάγγου - Η Καθημερινή
# Sentiment(polarity=0.0, subjectivity=0.0)
# Banco de la República anuncia que seguirá la compra de dólares - Portafolio.co
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ebay Kleinanzeigen: Warnung vor Abzocke bei Portal - Betrüger nutzen Trick bei Paypal | Region - Frankfurter Neue Presse
# Sentiment(polarity=0.0, subjectivity=0.0)
# Two Burnaby residents pay $4.8 million in penalties to BCSC in Ponzi scheme fraud - Vancouver Sun
# Sentiment(polarity=0.0, subjectivity=0.0)
# Two Burnaby residents pay $4.8 million in penalties to BCSC in Ponzi scheme fraud - Vancouver Sun
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tensões comerciais e Brexit são riscos para economia dos EUA, diz Fed - Sputnik Brasil
# Sentiment(polarity=0.0, subjectivity=0.0)
# Un problème de sécurité dans le réacteur finlandais d'Areva - Boursorama
# Sentiment(polarity=0.0, subjectivity=0.0)
# Volkswagen (VW) vz Outperform von Bernstein Research am 22.02.19 - finanzen.at
# Sentiment(polarity=0.0, subjectivity=0.0)
# Facebook planned to spy on Android phone users, internal emails reveal - ComputerWeekly.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Volkswagen dégage 15,6 milliards de profits - Le Figaro
# Sentiment(polarity=0.0, subjectivity=0.0)
# Una automotriz analiza ofrecer en Argentina un reloj para abrir las puertas y arrancar el motor - TN - Todo Noticias
# Sentiment(polarity=0.0, subjectivity=0.0)
# Lagit investigates claim that Naira is N184 to 1 dollar few hours to presidential election - Legit.ng
# Sentiment(polarity=-0.2, subjectivity=0.1)
# Forex market: CBN provides $268.4m, CNY46.3m for agric, raw materials - Premium Times
# Sentiment(polarity=-0.23076923076923078, subjectivity=0.46153846153846156)
# ¿Por qué fracasó el Airbus A380? - Infobae.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# O arquiteto da destruição da Enron saiu da prisão ao fim de 12 anos - Jornal de Negócios - Portugal
# Sentiment(polarity=0.0, subjectivity=0.0)
# United is doubling down on its business class offerings — and that could be good news for investors - Business Insider
# Sentiment(polarity=0.2722222222222222, subjectivity=0.44444444444444453)
# Are Cryptocurrencies More Trustworthy Than Stocks? - Forbes
# Sentiment(polarity=0.5, subjectivity=0.5)
# Richard Branson's Virgin Galactic takes first passenger into space - Stuff.co.nz
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Wyniki losowania EuroJackpot 22.02.2019 [Multi Multi, Kaskada, Mini Lotto, Ekstra Pensja] - Wiadomosci Gazeta.pl
# Sentiment(polarity=0.0, subjectivity=0.0)
# BMV cierra en positivo e ignora desplome de Televisa - ElEconomista
# Sentiment(polarity=0.0, subjectivity=0.0)
# Dólar cai no dia, a R$ 3,741, mas fecha a semana com valorização de 1% - UOL
# Sentiment(polarity=0.0, subjectivity=0.0)
# Cuidado mundo: mega alianza entre las alemanas BMW y Mercedes-Benz - Merca2.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Cuidado mundo: mega alianza entre las alemanas BMW y Mercedes-Benz - Merca2.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Cuidado mundo: mega alianza entre las alemanas BMW y Mercedes-Benz - Merca2.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Hong Kong's monetary chief to step down - Gulf Times
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# All the tech startups that have taken steps toward going public in 2019 — and those rumored to be eyeing an IPO - Business Insider
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Cupra predstavuje svoj prvý vlastný model. Agresívne SUV-kupé zaujme už na prvý pohľad - REFRESHER
# Sentiment(polarity=0.0, subjectivity=0.0)
# Deadly pig virus that has killed millions of piglets in the U.S. detected in Alberta for the second time - Global News
# Sentiment(polarity=-0.1, subjectivity=0.1)
# Deadly pig virus that has killed millions of piglets in the U.S. detected in Alberta for the second time - Global News
# Sentiment(polarity=-0.1, subjectivity=0.1)
# 今年美联储料仅加息一次我国央行预计盾币将愈加稳定趋于走强 - Indonesia Shang Bao
# Sentiment(polarity=0.0, subjectivity=0.0)
# 반도체 침체에 '규제 완화'…10년 만에 수도권 초대형 공장 - 국민일보
# Sentiment(polarity=0.0, subjectivity=0.0)
# Labor prüft Lebensmittel: Wurst aus neuem Discounter Mere nicht zum Verzehr geeignet - Mitteldeutsche Zeitung
# Sentiment(polarity=-0.5, subjectivity=0.5)
# 金沙擬加大路氹投資額 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# 傳下月發6虛銀牌照中資佔4個 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# Naira gains against dollar across markets ahead of elections, trades N358/$1 at parallel market - Pulse Nigeria
# Sentiment(polarity=0.0, subjectivity=0.0)
# Fired Amazon Employee With Crohn's Files Lawsuit Over Bathroom Access - The Mighty
# Sentiment(polarity=0.4, subjectivity=0.9)
# Fired Amazon Employee With Crohn's Files Lawsuit Over Bathroom Access - The Mighty
# Sentiment(polarity=0.4, subjectivity=0.9)
# Elon Musk turns to Morgan Stanley for five monster mortgages - National Mortgage News
# Sentiment(polarity=0.0, subjectivity=0.0)
# 手機5G勢勁12股市值日漲722億恒指全周飆915點直撲二萬九關 - 雅虎香港新聞
# Sentiment(polarity=0.0, subjectivity=0.0)
# 樓市升溫綠楊新邨反價沽太古城巨無霸近半億成交 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# 內地一手樓價升10% 年半最勁 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# Divers - libération
# Sentiment(polarity=0.0, subjectivity=0.0)
# ​Six start-up décrochent des partenariats avec le groupe BCP - libération
# Sentiment(polarity=0.0, subjectivity=0.0)
# 香港電訊多賺2% 派息39.17仙 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# AVA 228首日沽46伙 - 香港蘋果日報
# Sentiment(polarity=0.0, subjectivity=0.0)
# Efter pedofilskandalen: Ikea tar bort reklam på Youtube - Aftonbladet
# Sentiment(polarity=0.0, subjectivity=0.0)
# Trudeau government posted $300-million surplus in the first nine months of 2018-19 - Financial Post
# Sentiment(polarity=0.125, subjectivity=0.16666666666666666)
# Richard Branson’s Virgin Galactic flight sends first test passenger into space - Global News
# Sentiment(polarity=0.125, subjectivity=0.16666666666666666)
# Richard Branson’s Virgin Galactic flight sends first test passenger into space - Global News
# Sentiment(polarity=0.125, subjectivity=0.16666666666666666)
# Car2go announces $1.5B merger with BMW's car-sharing service - Daily Hive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Car2go announces $1.5B merger with BMW's car-sharing service - Daily Hive
# Sentiment(polarity=0.0, subjectivity=0.0)
# The Trade Desk soars 31% as sell-side praises Q4 blowout - Seeking Alpha
# Sentiment(polarity=0.0, subjectivity=0.0)
# Soriana tiene sus peores resultados en por lo menos 10 años - Expansión
# Sentiment(polarity=0.0, subjectivity=0.0)
# Software development in the cloud: Benefits and challenges - TechGenix
# Sentiment(polarity=0.0, subjectivity=0.0)
# Crude Oil Price Update - High-to-High Analysis Indicates Rally is Slowing - FX Empire
# Sentiment(polarity=-0.7, subjectivity=1.0)
# Is the Jaguar I-Pace better than a Tesla? - NEWS.com.au
# Sentiment(polarity=0.5, subjectivity=0.5)
# La plus grosse usine de Nutella au monde rouvrira lundi, annonce Ferrero France - RTBF
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tesla, tour in Italia per provare Model 3. Il via da Milano, Bologna e Padova, poi Roma e Firenze - Il Gazzettino
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tesla se nebrání sdílení technologie Autopilot s ostatními výrobci - Hybrid.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# Apps send intimate user data to Facebook —report - The Punch
# Sentiment(polarity=0.2, subjectivity=0.6)
# Freshii CEO pledges to fix declining sales - CBC.ca
# Sentiment(polarity=0.0, subjectivity=0.0)
# Freshii CEO pledges to fix declining sales - CBC.ca
# Sentiment(polarity=0.0, subjectivity=0.0)
# Flight attendants say American Airlines' sick leave policy discriminates against women - Dallas News
# Sentiment(polarity=-0.35714285714285715, subjectivity=0.42857142857142855)
# Volkswagen Gol, Voyage e Up! vão acabar em 2021 - Jornal do Carro Estadão
# Sentiment(polarity=0.0, subjectivity=0.0)
# Salão Duas Rodas: debandada geral? - Motonline
# Sentiment(polarity=0.0, subjectivity=0.0)
# Salão Duas Rodas: debandada geral? - Motonline
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bitcoin Hits $4K, Ripple Moves 100 Million XRP, and Latin America's Biggest Investment Bank Goes Crypto - The Daily Hodl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Le vaisseau spatial de Virgin Galactic a atteint 90 km d'altitude - lalibre.be
# Sentiment(polarity=0.0, subjectivity=0.0)
# Zucht. Ook CDA wil wetten tegen nepnieuws - Geenstijl.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Here are the winning numbers for the PowerBall and PowerBall Plus draws for Friday, February 22 - News24
# Sentiment(polarity=0.5, subjectivity=0.75)
# Her har de laget klassens tøffeste bil - ABC Nyheter
# Sentiment(polarity=0.0, subjectivity=0.0)
# USD/CAD Canadian Dollar Higher on Stronger Oil and Softer Dollar - MarketPulse
# Sentiment(polarity=0.25, subjectivity=0.5)
# USD/CAD Canadian Dollar Higher on Stronger Oil and Softer Dollar - MarketPulse
# Sentiment(polarity=0.25, subjectivity=0.5)
# Aktien New York: Hoffen auf Handelsgespräche - Kursdesaster bei Kraft Heinz - Boerse-express.com
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Zarząd PLL LOT porozumiał się ze związkami zawodowymi | Z kraju - TVN24 BiS
# Sentiment(polarity=0.0, subjectivity=0.0)
# Canada's energy regulator endorses Trans Mountain pipeline - KOMO News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Zillow is making a big bet on flipping homes. Its new CEO could 'make this gamble work': RBC's Mahaney - CNBC
# Sentiment(polarity=0.06818181818181818, subjectivity=0.2772727272727273)
# Sanciones de Estados Unidos contra Venezuela ¿tienen un efecto bumerán? - Diario Granma
# Sentiment(polarity=0.0, subjectivity=0.0)
# 'Gesjoemel Volkswagen is een materiële fout' | Auto - AD.nl
# Sentiment(polarity=0.0, subjectivity=0.0)
# Kraft-Heinz, trema il colosso del ketchup: profondo rosso a Wall Street, -27% - Il Messaggero
# Sentiment(polarity=0.0, subjectivity=0.0)
# Wesfarmers half-year results 2019: Coles $1b special dividend - NEWS.com.au
# Sentiment(polarity=0.35714285714285715, subjectivity=0.5714285714285714)
# From Thatcher to Brexit: how UK carmakers were forced into the slow lane - Financial Times
# Sentiment(polarity=-0.20000000000000004, subjectivity=0.19999999999999998)
# «Le Maroc est le pays le plus propice pour notre développement en Afrique» - LE MATiN
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mercedes amorce la production du CLA deuxième du nom - Caradisiac.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nå kommer det viktige elektriske nyheter fra Volvo - Telemarksavisa
# Sentiment(polarity=0.0, subjectivity=0.0)
# Jugadores del Real Madrid estrenan automóvil en plena crisis del club - PASIONFUTBOL
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# La tasa de interés pegó la vuelta y ya está en 50% - La Voz del Interior
# Sentiment(polarity=0.0, subjectivity=0.0)
# Budget carrier Flair Airlines calls abrupt halt to new routes to Florida, California - Financial Post
# Sentiment(polarity=0.0037878787878787845, subjectivity=0.48484848484848486)
# American agriculture companies are sounding the alarm on Trump's trade war | Markets Insider - Business Insider
# Sentiment(polarity=0.0, subjectivity=0.0)
# Stephen Van Coller reflects on EOH's week from hell - TechCentral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Outdoor Mobile Coverage Map Launched By ComReg - TodayFM
# Sentiment(polarity=0.0, subjectivity=0.0)
# Hushållen dras med i Swedbanks aktieras - Svenska Dagbladet
# Sentiment(polarity=0.0, subjectivity=0.0)
# Απογοητευτικές οι εκτιμήσεις για την φετινή ελαιοπαραγωγή στη χώρα - Newsbeast.gr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Basic Energy completes deal for minority stake in Thai firm - BusinessWorld Online
# Sentiment(polarity=-0.1, subjectivity=0.2625)
# Online sledování autobusů spouští i Jihlava, Pražané na takovou možnost stále čekají - E15.cz
# Sentiment(polarity=0.0, subjectivity=0.0)
# As 50 startups que podem ser os próximos unicórnios; duas são brasileiras - InfoMoney
# Sentiment(polarity=0.0, subjectivity=0.0)
# Con la tessera sanitaria le spese si consultano online - Economia - Agenzia ANSA
# Sentiment(polarity=0.0, subjectivity=0.0)
# Los negociazos del multimillonario detrás del concierto Venezuela Aid Live - Pulzo.com
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Anche l'Italia contro il 5G di Huawei: la Lega chiede interventi dopo monito USA - HDblog
# Sentiment(polarity=0.0, subjectivity=0.0)
# Southeastern Grocers to shut 22 stores - Supermarket News
# Sentiment(polarity=0.0, subjectivity=0.0)
# Criptovalute: Ripple nuovi target choc, da maneggiare con cura - Trend-online.com
# Sentiment(polarity=0.0, subjectivity=0.0)
# Dow Jones Today Led By Intel, Pfizer; 3 Stocks Explode Higher On Earnings - Investor's Business Daily
# Sentiment(polarity=0.125, subjectivity=0.25)
# Estados Unidos advertirá en el Mobile World Congress sobre los peligros de adoptar Huawei para la red 5G - Infobae America
# Sentiment(polarity=0.0, subjectivity=0.0)
# Bajban van a közkedvelt ketchup gyártója - Origo
# Sentiment(polarity=0.0, subjectivity=0.0)
# Cannabis lollipops and gummy bears should not be legalized, says Ottawa's Medical Officer of Health - Ottawa Citizen
# Sentiment(polarity=0.0, subjectivity=0.0)
# Rachid Azaoum, patron de franchises Quick-Burger King, se lance en politique avec le CDH - lalibre.be
# Sentiment(polarity=0.0, subjectivity=0.0)
# Mercado Libre prepara dos centros de distribución y almacenamiento en México para competir con Amazon - Xataka México
# Sentiment(polarity=0.0, subjectivity=0.0)
# El descubrimiento de cámaras en los sistemas de entretenimiento de algunos aviones ha despertado preocupación por la privacidad - Genbeta
# Sentiment(polarity=0.0, subjectivity=0.0)
